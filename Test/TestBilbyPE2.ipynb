# %%
# limit the thread used by numpy 
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"  

import numpy as np
import scipy.interpolate as interp 
try:
    import cupy as xp
    import cupyx.scipy.interpolate as xinterp
    # print("has cupy")
except (ImportError, ModuleNotFoundError) as e:
    import numpy as xp
    import scipy.interpolate as xinterp  
    # print("no cupy")

from tqdm import tqdm
import pickle
import matplotlib.pyplot as plt
# import matplotlib
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.family'] = 'serif'

from Triangle.Constants import *
from Triangle.Orbit import * 
from Triangle.Noise import *
from Triangle.FFTTools import *
from Triangle.TDI import *
from Triangle.Data import * 

from Triangle_BBH.Waveform import * 
from Triangle_BBH.Response import *
from Triangle_BBH.Utils import *
from Triangle_BBH.Fisher import *

# import multiprocessing

np.random.seed(114515)
xp.random.seed(114515)
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# has cupy
# has cupy
# has BBHx waveform

# %% [markdown]
# ## Data settings

# %%
t_start = 10. * DAY # start time in s
Tobs = 5. * DAY # data length in s 
t_end = t_start + Tobs # end time in s 
dt = 10. # time cadance in s 
fsample = 1. / dt # sampling rate in Hz 
data_frequencies = np.fft.rfftfreq(n=int(Tobs/dt), d=dt) # frequecies where waveform will be calculated 
delta_f = 1. / Tobs

data_frequencies.shape
# Out:
# (21601,)

# %%
# mask the "null" frequencies, which may cause singularity in the calculation of likelihood 
mask = np.ones_like(data_frequencies, dtype=bool)
for i in range(1, 40): 
    mask_idx = np.where(np.abs(data_frequencies - i*0.025)<i*3e-4)[0]
    mask[mask_idx] = False 
data_frequencies = data_frequencies[mask]

# remove the frequencies below Taiji sensitive band 
mask = np.where(data_frequencies > 1e-5)[0]
data_frequencies = data_frequencies[mask]
data_frequencies_GPU = xp.array(data_frequencies)

data_frequencies.shape
# Out:
# (21077,)

# %% [markdown]
# ## Set response model

# %%
# the path of Taiji orbit 
orbit_GPU = Orbit(OrbitDir="../../Triangle-Simulator/OrbitData/MicroSateOrbitEclipticTCB") # create individial orbit objects for CPU and GPU to avoid the confusion of numpy / cupy orbit data 

# initialize  waveform generator 
WFG_GPU = BBHxWaveformGenerator(mode="primary", use_gpu=True)

# initialize response generator 
FDTDI_GPU = BBHxFDTDIResponseGenerator(orbit_class=orbit_GPU, waveform_generator=WFG_GPU, use_gpu=True)

# response settings 
response_kwargs_GPU = dict(
    modes=[(2,2)], 
    tmin=t_start / DAY, # start time in day 
    tmax=t_end / DAY, # end time in day  
    TDIGeneration="2nd", # "1st" or "2nd"
    optimal_combination=True, # True for AET, False for XYZ 
    output_by_mode=False, 
    interpolation=True,
)

# %% [markdown]
# ## Waveform generation

# %%
mbhb_parameters = {
    'chirp_mass': np.power(10., np.random.uniform(5.5, 6.5)), # [Solar mass], for chirp_mass of 10^5 or smaller, a smaller dt is needed
    'mass_ratio': np.random.uniform(0.1, 1.), 
    'spin_1z': np.random.uniform(-0.99, 0.99),
    'spin_2z': np.random.uniform(-0.99, 0.99),
    'coalescence_time': np.random.uniform(t_start + DAY, t_end) / DAY, # [day], start from t_start to ensure that at least 1-day waveform is within the data
    'coalescence_phase': np.random.uniform(0, TWOPI),
    'luminosity_distance': np.power(10., np.random.uniform(4., 5.)), # [MPC]
    'inclination': np.arccos(np.random.uniform(-1., 1.)), # [rad]
    'longitude': np.random.uniform(0, TWOPI), # [rad]
    'latitude': np.arcsin(np.random.uniform(-1., 1.)), # [rad]
    'psi': np.random.uniform(0, PI) # [rad]
    }
mbhb_parameters
# Out:
# {'chirp_mass': 336191.35143253714,
#  'mass_ratio': 0.338024724135096,
#  'spin_1z': 0.05524593654909138,
#  'spin_2z': -0.8656789340019758,
#  'coalescence_time': 12.81373152271136,
#  'coalescence_phase': 2.6945874770778175,
#  'luminosity_distance': 15584.553036608575,
#  'inclination': 0.4784682961157525,
#  'longitude': 2.659019392497368,
#  'latitude': -0.7391540459115268,
#  'psi': 0.2209530247476669}

# %%
wf_channels = FDTDI_GPU.Response(mbhb_parameters, data_frequencies_GPU, **response_kwargs_GPU)
wf_channels.shape
# Out:
# (3, 21077)

# %% [markdown]
# ## Noise generation

# %%
arm_time = (t_start + t_end) / 2. 
arms = dict()
for key in MOSA_labels:
    arms[key] = orbit_GPU.LTTfunctions()[key](arm_time)
# print("arm lengths:", arms)

# theoretical PSDs at the given armlengths 
PSDfunc = TDIPSDs()
PSD_channels = np.array([
    PSDfunc.PSD_A2_unequal(data_frequencies, arms), 
    PSDfunc.PSD_E2_unequal(data_frequencies, arms), 
    PSDfunc.PSD_T2_unequal(data_frequencies, arms)
])

# generate frequency-domain noises as Gaussian and stationary 
Re_tmp = np.random.normal(scale=np.sqrt(PSD_channels / 4. / delta_f))
Im_tmp = np.random.normal(scale=np.sqrt(PSD_channels / 4. / delta_f))
noise_channels = xp.array(Re_tmp + 1.j * Im_tmp) 

# covariance matrix 
CovMat = np.array([
    [PSD_channels[0], np.zeros_like(PSD_channels[0]), np.zeros_like(PSD_channels[0])],
    [np.zeros_like(PSD_channels[0]), PSD_channels[1], np.zeros_like(PSD_channels[0])],
    [np.zeros_like(PSD_channels[0]), np.zeros_like(PSD_channels[0]), PSD_channels[2]]
]) / 4. / delta_f # (3, 3, Nf)

# inverse of covmatrix
InvCovMat = np.linalg.inv(np.transpose(CovMat, (2, 0, 1))) # (Nf, 3, 3)
InvCovMat[:, 2, 2] *= 0. # use A, E channels only in the following analysis 

PSD_channels.shape, noise_channels.shape, InvCovMat.shape
# Out:
# ((3, 21077), (3, 21077), (21077, 3, 3))

# %% [markdown]
# ## Data combination

# %%
data_channels = wf_channels + noise_channels

# %%
for ichannel, nchannel in enumerate(["A", "E", "T"]): 
    plt.loglog(data_frequencies, np.abs(data_channels[ichannel].get()), linewidth=1, alpha=0.5, color=BLUE)
    plt.loglog(data_frequencies, np.abs(wf_channels[ichannel].get()), color=RED, linestyle=":")
    plt.loglog(data_frequencies, np.sqrt(PSD_channels[ichannel] * Tobs / 2.), color="grey", linestyle="--")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Frequency-domain data (1/Hz)")
# Out:
# Text(0, 0.5, 'Frequency-domain data (1/Hz)')

# %% [markdown]
# ## Fisher analysis
# calculate the theoretical bounds

# %%
def fisher_waveform_wrapper(param_dict, frequencies):
    res = FDTDI_GPU.Response(
        parameters=param_dict, 
        freqs=xp.array(frequencies),  
        **response_kwargs_GPU, 
    )
    return res.get()

# set initial steps 
analyze_param_step_dict = {
    'chirp_mass': 10.,
    'mass_ratio': 0.01,
    'spin_1z': 0.01,
    'spin_2z': 0.01,
    'coalescence_time': 0.001,
    'coalescence_phase': 0.001,
    'luminosity_distance': 10.,
    'inclination': 0.01,
    'longitude': 0.01,
    'latitude': 0.01,
    'psi': 0.01
    }
for k, v in analyze_param_step_dict.items():
    analyze_param_step_dict[k] = -v 

FIM = MultiChannelFisher(
    waveform_generator=fisher_waveform_wrapper, 
    param_dict=mbhb_parameters, 
    analyze_param_step_dict=analyze_param_step_dict, 
    frequency=data_frequencies, 
    inverse_covariance=InvCovMat, 
    verbose=1,
)

FIM.auto_test_step()
FIM.calculate_Fisher()
FIM.calculate_errors()
# Out:
# 11 parameters in total: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# 11 analyzed parameters: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# parameters whose steps should be tested: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
#
#  ========= testing parameter chirp_mass ==========
# error = 1.5894999228778894
# shift = 5.0 relative diff = 4.926133216833851e-06
# shift of parameter chirp_mass is 5.0
#
#  ========= testing parameter mass_ratio ==========
# error = 0.004884557291948826
# shift = 0.005 relative diff = 0.004689366497698766
# error = 0.004864153150842999
# shift = 0.0025 relative diff = 0.005692165979965461
# error = 0.004854445119821042
# shift = 0.00125 relative diff = 0.0025850727089815873
# error = 0.004849696723122816
# shift = 0.000625 relative diff = 0.0012405873081912885
# error = 0.004847349405914785
# shift = 0.0003125 relative diff = 0.0006089056014207346
# error = 0.004846182535761093
# shift = 0.00015625 relative diff = 0.00030155527566078593
# error = 0.00484560080398108
# shift = 7.8125e-05 relative diff = 0.0001500463287806887
# error = 0.004845310364926485
# shift = 3.90625e-05 relative diff = 7.4839668978571e-05
# shift of parameter mass_ratio is 3.90625e-05
#
#  ========= testing parameter spin_1z ==========
# error = 0.00572392819048761
# shift = 0.005 relative diff = 0.0008131980047373421
# error = 0.005723242063405321
# shift = 0.0025 relative diff = 0.0007965443814523992
# error = 0.005723689033351279
# shift = 0.00125 relative diff = 4.968135318943122e-05
# shift of parameter spin_1z is 0.00125
#
#  ========= testing parameter spin_2z ==========
# error = 0.011861662961523705
# shift = 0.005 relative diff = 5.950076310331733e-06
# shift of parameter spin_2z is 0.005
#
#  ========= testing parameter coalescence_time ==========
# error = 0.00037389314488042247
# shift = 0.0005 relative diff = 0.16815026537225866
# error = 0.00032251457887880414
# shift = 0.00025 relative diff = 0.23069495939183163
# error = 0.00030957414901756886
# shift = 0.000125 relative diff = 0.08972706205265288
# error = 0.0003063628821347172
# shift = 6.25e-05 relative diff = 0.022787612612867852
# error = 0.0003055619610759615
# shift = 3.125e-05 relative diff = 0.005673799982433217
# error = 0.00030536186089480334
# shift = 1.5625e-05 relative diff = 0.0014163742159605383
# error = 0.0003053118469340428
# shift = 7.8125e-06 relative diff = 0.0003539431220241619
# error = 0.00030529934564013704
# shift = 3.90625e-06 relative diff = 8.847037677861487e-05
# shift of parameter coalescence_time is 3.90625e-06
#
#  ========= testing parameter coalescence_phase ==========
# error = 0.013850025944404444
# shift = 0.0005 relative diff = 2.8647517452116986e-08
# shift of parameter coalescence_phase is 0.0005
#
#  ========= testing parameter luminosity_distance ==========
# error = 2.445583059263815
# shift = 5.0 relative diff = 8.01754872150208e-05
# shift of parameter luminosity_distance is 5.0
#
#  ========= testing parameter inclination ==========
# error = 0.027982682142717617
# shift = 0.005 relative diff = 0.0010434108427589137
# error = 0.02801211852574406
# shift = 0.0025 relative diff = 0.0013030368160790976
# error = 0.02802689687470652
# shift = 0.00125 relative diff = 0.0006557363972032232
# error = 0.028034301140811204
# shift = 0.000625 relative diff = 0.00032892914877679307
# error = 0.02803800705521922
# shift = 0.0003125 relative diff = 0.00016473063790797268
# error = 0.02803986095765734
# shift = 0.00015625 relative diff = 8.243195372490197e-05
# shift of parameter inclination is 0.00015625
#
#  ========= testing parameter longitude ==========
# error = 0.005211428024651571
# shift = 0.005 relative diff = 0.0005172462487307099
# error = 0.005209896617480184
# shift = 0.0025 relative diff = 0.0005698685915561688
# error = 0.00520942003349279
# shift = 0.00125 relative diff = 0.00016443907502359915
# error = 0.005209254091694089
# shift = 0.000625 relative diff = 5.227951614788702e-05
# shift of parameter longitude is 0.000625
#
#  ========= testing parameter latitude ==========
# error = 0.0072800446129246115
# shift = 0.005 relative diff = 0.0008701425722607423
# error = 0.007274171398514268
# shift = 0.0025 relative diff = 0.0010637086893880898
# error = 0.007271350860669799
# shift = 0.00125 relative diff = 0.0004980379548479425
# error = 0.007269969703359003
# shift = 0.000625 relative diff = 0.00024051868908969145
# error = 0.007269285724260077
# shift = 0.0003125 relative diff = 0.00011816203342671131
# error = 0.007268945182386026
# shift = 0.00015625 relative diff = 5.8608265002124105e-05
# shift of parameter latitude is 0.00015625
#
#  ========= testing parameter psi ==========
# error = 0.013851346771951517
# shift = 0.005 relative diff = 2.3582380487870678e-06
# shift of parameter psi is 0.005
# all parameters tested.
# errors:
# {'chirp_mass': 10.533534890143322, 'mass_ratio': 0.0007601105768640365, 'spin_1z': 0.004294593126500909, 'spin_2z': 0.014492202358339432, 'coalescence_time': 2.144426334384018e-05, 'coalescence_phase': 0.13195373702822305, 'luminosity_distance': 364.25414520154465, 'inclination': 0.04538628525622658, 'longitude': 0.00639535458914946, 'latitude': 0.00618541255368804, 'psi': 0.13038872902062862}

# %%
FIM.param_errors
# Out:
# {'chirp_mass': 10.533534890143322,
#  'mass_ratio': 0.0007601105768640365,
#  'spin_1z': 0.004294593126500909,
#  'spin_2z': 0.014492202358339432,
#  'coalescence_time': 2.144426334384018e-05,
#  'coalescence_phase': 0.13195373702822305,
#  'luminosity_distance': 364.25414520154465,
#  'inclination': 0.04538628525622658,
#  'longitude': 0.00639535458914946,
#  'latitude': 0.00618541255368804,
#  'psi': 0.13038872902062862}

# %%
opt_SNR = FrequencyDomainCovarianceSNR(wf_channels.get(), InvCovMat)
opt_SNR
# Out:
# 2606.566618798435

# %% [markdown]
# ## Likelihood

# %%
Like = Likelihood(
    response_generator=FDTDI_GPU, 
    frequency=data_frequencies_GPU, 
    data=data_channels,
    invserse_covariance_matrix=InvCovMat, 
    response_parameters=response_kwargs_GPU, 
    use_gpu=True,
)
# Out:
# number of freuqncies: 21077
# min and max frequencies: 1.1574074074074073e-05 0.04939814814814815
# response kwargs: {'modes': [(2, 2)], 'tmin': 10.0, 'tmax': 15.0, 'TDIGeneration': '2nd', 'optimal_combination': True, 'output_by_mode': False, 'interpolation': True}

# %%
fiducial_param_arr = ParamDict2ParamArr(mbhb_parameters)

N_test=101
test_idx = 0 # lgMc 
test_params = np.linspace(-1e-3, 1e-3, N_test) + fiducial_param_arr[test_idx]

full_lls = [] # store the full loglikelihood 
for i_test in range(N_test):
    tmp_params = np.array(fiducial_param_arr).copy()
    tmp_params[test_idx] = test_params[i_test]
    full_lls.append(Like.full_log_like(tmp_params))
full_lls = np.array(full_lls)

plt.plot((test_params - fiducial_param_arr[test_idx])*1e3, full_lls - np.max(full_lls), label="full logLike")
plt.xlabel(r'$\Delta {\rm lg} \mathcal{M}c \ (10^{-3})$')
plt.ylabel(r'$\Delta {\rm ln} \mathcal{L}$')
plt.legend(frameon=False)

# %% [markdown]
# ## Bilby wrapper

# %%
import bilby

# %%
priors = bilby.core.prior.PriorDict()
priors["chirp_mass"] = bilby.prior.Uniform(minimum=mbhb_parameters["chirp_mass"]-10.*FIM.param_errors["chirp_mass"], maximum=mbhb_parameters["chirp_mass"]+10.*FIM.param_errors["chirp_mass"], name='chirp_mass', latex_label='$\mathcal{M}_c$')
priors["mass_ratio"] = bilby.prior.Uniform(minimum=max(0.1, mbhb_parameters["mass_ratio"]-10.*FIM.param_errors["mass_ratio"]), maximum=min(1., mbhb_parameters["mass_ratio"]+10.*FIM.param_errors["mass_ratio"]), name="mass_ratio", latex_label='$q$')
priors["spin_1z"] = bilby.prior.Uniform(minimum=max(-0.99, mbhb_parameters["spin_1z"]-10.*FIM.param_errors["spin_1z"]), maximum=min(0.99, mbhb_parameters["spin_1z"]+10.*FIM.param_errors["spin_1z"]), name="spin_1z", latex_label='$\chi_{z1}$')
priors["spin_2z"] = bilby.prior.Uniform(minimum=max(-0.99, mbhb_parameters["spin_2z"]-10.*FIM.param_errors["spin_2z"]), maximum=min(0.99, mbhb_parameters["spin_2z"]+10.*FIM.param_errors["spin_2z"]), name="spin_2z", latex_label='$\chi_{z2}$')
priors["coalescence_time"] = bilby.prior.Uniform(minimum=mbhb_parameters["coalescence_time"]-10.*FIM.param_errors["coalescence_time"], maximum=mbhb_parameters["coalescence_time"]+10.*FIM.param_errors["coalescence_time"], name="coalescence_time", latex_label='$t_c$') 
priors["coalescence_phase"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="coalescence_phase", latex_label='$\\varphi_c$', boundary="periodic")
priors["luminosity_distance"] = bilby.prior.Uniform(minimum=mbhb_parameters["luminosity_distance"]-10.*FIM.param_errors["luminosity_distance"], maximum=mbhb_parameters["luminosity_distance"]+10.*FIM.param_errors["luminosity_distance"], name="luminosity_distance", latex_label='$d_L$')
priors["inclination"] = bilby.prior.Sine(minimum=0., maximum=PI, name="inclination", latex_label='$\iota$')
priors["longitude"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="longitude", latex_label='$\lambda$', boundary="periodic")
priors["latitude"] = bilby.prior.Cosine(minimum=-PI/2., maximum=PI/2., name="latitude", latex_label='$\\beta$')
priors["psi"] = bilby.prior.Uniform(minimum=0., maximum=PI, name="psi", latex_label='$\psi$', boundary="periodic")

# %%
priors
# Out:
# {'chirp_mass': Uniform(minimum=336086.0160836357, maximum=336296.6867814386, name='chirp_mass', latex_label='$\\mathcal{M}_c$', unit=None, boundary=None),
#  'mass_ratio': Uniform(minimum=0.3304236183664556, maximum=0.34562582990373636, name='mass_ratio', latex_label='$q$', unit=None, boundary=None),
#  'spin_1z': Uniform(minimum=0.012300005284082288, maximum=0.09819186781410047, name='spin_1z', latex_label='$\\chi_{z1}$', unit=None, boundary=None),
#  'spin_2z': Uniform(minimum=-0.99, maximum=-0.7207569104185815, name='spin_2z', latex_label='$\\chi_{z2}$', unit=None, boundary=None),
#  'coalescence_time': Uniform(minimum=12.81351708007792, maximum=12.813945965344798, name='coalescence_time', latex_label='$t_c$', unit=None, boundary=None),
#  'coalescence_phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='coalescence_phase', latex_label='$\\varphi_c$', unit=None, boundary='periodic'),
#  'luminosity_distance': Uniform(minimum=11942.011584593129, maximum=19227.09448862402, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None),
#  'inclination': Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None),
#  'longitude': Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic'),
#  'latitude': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None),
#  'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}

# %%
class bilby_likelihood_wrapper(bilby.Likelihood):
    def __init__(self, triangle_likelihood, likelihood_type="full"):
        """ wrap a triangle likelihood to get a bilby likelihood, type can be "full" or "heterodyned" """
        super().__init__(
            parameters={
                'chirp_mass': None,
                'mass_ratio': None,
                'spin_1z': None,
                'spin_2z': None,
                'coalescence_time': None,
                'coalescence_phase': None,
                'luminosity_distance': None,
                'inclination': None,
                'longitude': None,
                'latitude': None,
                'psi': None
            }
        )
        if likelihood_type == "full":
            self.LLfunc = triangle_likelihood.full_log_like
        elif likelihood_type == "heterodyned":
            self.LLfunc = triangle_likelihood.het_log_like
        else:
            raise ValueError("wrong likelihood type. it should only be full or heterodyned.")

    def log_likelihood(self):
        return self.LLfunc(ParamDict2ParamArr(self.parameters))

# %%
BLike_full = bilby_likelihood_wrapper(triangle_likelihood=Like, likelihood_type="full")

# %%
sampler_name = "nessai"
# sampler_name = "dynesty"

# %%
# import multiprocessing
# print("number of cpus =", multiprocessing.cpu_count())

result = bilby.run_sampler(
    likelihood=BLike_full, 
    priors=priors,
    sampler=sampler_name, 
    nlive=1000,
    walks=20,
    nact=50,
    maxmcmc=2000,
    dlogz=0.3,
    # npool=multiprocessing.cpu_count(),
    npool=None, 
    injection_parameters=mbhb_parameters, 
    outdir="../../Results/bilby_outdir",
    label="test_full_likelihood_5day2",
    plot=True,
    resume=False, 
    # resume=True, 
)
# Out:
# 18:59 bilby INFO    : Running for label 'test_full_likelihood_5day2', output will be saved to '../../Results/bilby_outdir'
# /home/ps/miniconda3/envs/tri_env/lib/python3.9/site-packages/bilby/core/utils/log.py:73: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   vdict[key] = str(getattr(sys.modules[key], "__version__", "N/A"))
# 18:59 bilby INFO    : Analysis priors:
# 18:59 bilby INFO    : chirp_mass=Uniform(minimum=336086.0160836357, maximum=336296.6867814386, name='chirp_mass', latex_label='$\\mathcal{M}_c$', unit=None, boundary=None)
# 18:59 bilby INFO    : mass_ratio=Uniform(minimum=0.3304236183664556, maximum=0.34562582990373636, name='mass_ratio', latex_label='$q$', unit=None, boundary=None)
# 18:59 bilby INFO    : spin_1z=Uniform(minimum=0.012300005284082288, maximum=0.09819186781410047, name='spin_1z', latex_label='$\\chi_{z1}$', unit=None, boundary=None)
# 18:59 bilby INFO    : spin_2z=Uniform(minimum=-0.99, maximum=-0.7207569104185815, name='spin_2z', latex_label='$\\chi_{z2}$', unit=None, boundary=None)
# 18:59 bilby INFO    : coalescence_time=Uniform(minimum=12.81351708007792, maximum=12.813945965344798, name='coalescence_time', latex_label='$t_c$', unit=None, boundary=None)
# 18:59 bilby INFO    : coalescence_phase=Uniform(minimum=0.0, maximum=6.283185307179586, name='coalescence_phase', latex_label='$\\varphi_c$', unit=None, boundary='periodic')
# 18:59 bilby INFO    : luminosity_distance=Uniform(minimum=11942.011584593129, maximum=19227.09448862402, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None)
# 18:59 bilby INFO    : inclination=Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None)
# 18:59 bilby INFO    : longitude=Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic')
# 18:59 bilby INFO    : latitude=Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None)
# 18:59 bilby INFO    : psi=Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')
# 18:59 bilby INFO    : Analysis likelihood class: <class '__main__.bilby_likelihood_wrapper'>
# 18:59 bilby INFO    : Analysis likelihood noise evidence: nan
# 18:59 bilby INFO    : Single likelihood evaluation took nan s
# 18:59 bilby WARNING : Supplied argument 'walks' not an argument of 'Nessai', removing.
# 18:59 bilby WARNING : Supplied argument 'nact' not an argument of 'Nessai', removing.
# 18:59 bilby WARNING : Supplied argument 'maxmcmc' not an argument of 'Nessai', removing.
# 18:59 bilby WARNING : Supplied argument 'dlogz' not an argument of 'Nessai', removing.
# 18:59 bilby INFO    : Using sampler Nessai with kwargs {'n_steps': 10, 'n_accept': None, 'step_type': 'gaussian', 'step_kwargs': None, 'plot_chain': False, 'plot_history': False, 'enforce_likelihood_threshold': True, 'ensemble_fraction': 0.5, 'rng': None, 'flow_config': None, 'training_config': None, 'output': '../../Results/bilby_outdir/test_full_likelihood_5day2_nessai/', 'poolsize': 1000, 'plot': True, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'max_n_clusters': None, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False, 'augment_dims': 1, 'generate_augment': 'gaussian', 'marginalise_augment': False, 'n_marg': 50, 'nlive': 1000, 'stopping': 0.1, 'max_iteration': None, 'checkpointing': True, 'checkpoint_interval': 600, 'checkpoint_on_iteration': False, 'checkpoint_on_training': False, 'checkpoint_callback': None, 'logging_interval': 60, 'log_on_iteration': False, 'resume_file': 'nested_sampler_resume.pkl', 'seed': None, 'pool': None, 'close_pool': None, 'n_pool': None, 'proposal_plots': False, 'prior_sampling': False, 'analytic_priors': False, 'maximum_uninformed': None, 'uninformed_proposal': None, 'uninformed_acceptance_threshold': None, 'uninformed_proposal_kwargs': None, 'flow_proposal_class': None, 'flow_class': None, 'training_frequency': None, 'train_on_empty': True, 'cooldown': 200, 'memory': False, 'reset_weights': False, 'reset_permutations': False, 'reset_flow': False, 'retrain_acceptance': True, 'reset_acceptance': False, 'acceptance_threshold': 0.01, 'shrinkage_expectation': 'logt', 'trace_parameters': None, 'resume': False, 'resume_data': None, 'weights_file': None, 'weights_path': None, 'exit_code': 130, 'pytorch_threads': 1, 'eps': None, 'torch_dtype': None, 'disable_vectorisation': False, 'likelihood_chunksize': None, 'allow_multi_valued_likelihood': None, 'parallelise_prior': None, 'result_extension': 'hdf5', 'plot_indices': True, 'plot_posterior': False, 'plot_logXlogL': True, 'posterior_sampling_method': None, 'nessai_log_level': None, 'nessai_logging_stream': 'stdout', 'nessai_plot': True, 'nessai_likelihood_constraint': True}
# 07-14 18:59 nessai INFO    : Running Nessai version 0.14.0.post0
# 07-14 18:59 nessai INFO    : pool and n_pool are none, no multiprocessing pool
# 07-14 18:59 nessai INFO    : Initialising nested sampler
# /home/ps/miniconda3/envs/tri_env/lib/python3.9/site-packages/nessai/utils/logging.py:133: FutureWarning: setup_logger is deprecated, use configure_logger instead
#   warnings.warn(
# 07-14 18:59 nessai WARNING : Multiprocessing pool has already been configured.
# 07-14 18:59 nessai WARNING : Removing unused keyword arguments ({'enforce_likelihood_threshold', 'augment_dims', 'generate_augment', 'max_n_clusters', 'plot_history', 'marginalise_augment', 'step_type', 'n_steps', 'ensemble_fraction', 'n_marg', 'n_accept', 'plot_chain', 'step_kwargs'}) from kwargs for FlowProposal. These are valid keyword arguments but correspond to other proposal classes.
# 07-14 18:59 nessai INFO    : Passing kwargs to FlowProposal: {'training_config': None, 'poolsize': 1000, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False}
# 07-14 18:59 nessai WARNING : Signal handling is disabled. nessai will not automatically checkpoint when exited.
# 07-14 18:59 nessai INFO    : No reparameterisations provided, using default reparameterisations included in FlowProposal
# 07-14 18:59 nessai INFO    : Adding reparameterisations from: {}
# 07-14 18:59 nessai INFO    : Assuming fallback reparameterisation (ScaleAndShift) for ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi'] with kwargs: {'estimate_scale': True, 'estimate_shift': True, 'prior_bounds': {'chirp_mass': array([336086.01608364, 336296.68678144]), 'mass_ratio': array([0.33042362, 0.34562583]), 'spin_1z': array([0.01230001, 0.09819187]), 'spin_2z': array([-0.99      , -0.72075691]), 'coalescence_time': array([12.81351708, 12.81394597]), 'coalescence_phase': array([0.        , 6.28318531]), 'luminosity_distance': array([11942.01158459, 19227.09448862]), 'inclination': array([0.        , 3.14159265]), 'longitude': array([0.        , 6.28318531]), 'latitude': array([-1.57079633,  1.57079633]), 'psi': array([0.        , 3.14159265])}}.
# 07-14 18:59 nessai INFO    : x space parameters: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# 07-14 18:59 nessai INFO    : x prime space parameters: ['chirp_mass_prime', 'mass_ratio_prime', 'spin_1z_prime', 'spin_2z_prime', 'coalescence_time_prime', 'coalescence_phase_prime', 'luminosity_distance_prime', 'inclination_prime', 'longitude_prime', 'latitude_prime', 'psi_prime']
# 07-14 18:59 nessai INFO    : Overwriting fuzz factor with expansion fraction
# 07-14 18:59 nessai INFO    : New fuzz factor: 1.1575579117706545
# 07-14 18:59 nessai INFO    : Verifying rescaling functions
# 07-14 18:59 nessai INFO    : Rescaling functions are invertible
# 07-14 18:59 nessai INFO    : Populating initial live points
# 07-14 18:59 nessai INFO    : Populated 100 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 200 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 300 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 400 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 500 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 600 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 700 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 800 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 900 / 1000 live points
# 07-14 18:59 nessai INFO    : Populated 1000 / 1000 live points
# 07-14 18:59 nessai INFO    : Starting nested sampling loop
# 07-14 19:00 nessai INFO    : it:  1000: Rolling KS test: D=0.028, p-value=0.2046
# 07-14 19:00 nessai INFO    : it:  1000: n eval: 3000 H: 7.91 dlogZ: 2915350.530 logZ: -4118014.149 +/- 0.089 logLmax: -1202662.62
# 07-14 19:01 nessai INFO    : it:  1569: n eval: 6000 H: 8.48 dlogZ: 2624824.405 logZ: -3827488.592 +/- 0.092 logLmax: -1202662.62
# 07-14 19:02 nessai INFO    : it:  2000: Rolling KS test: D=0.006, p-value=0.9268
# 07-14 19:02 nessai INFO    : Switching to FlowProposal
# 07-14 19:03 nessai INFO    : it:  2001: n eval: 10326 H: 8.91 dlogZ: 3171719.521 logZ: -3691760.140 +/- 0.094 logLmax: -520038.62
# 07-14 19:04 nessai INFO    : it:  2332: n eval: 13374 H: 9.24 dlogZ: 3088680.962 logZ: -3608721.911 +/- 0.096 logLmax: -520038.62
# 07-14 19:06 nessai INFO    : it:  2649: n eval: 17062 H: 9.56 dlogZ: 3015486.822 logZ: -3535528.088 +/- 0.098 logLmax: -520038.62
# 07-14 19:08 nessai INFO    : it:  2928: n eval: 21856 H: 9.84 dlogZ: 3060051.448 logZ: -3472973.269 +/- 0.099 logLmax: -412918.89
# 07-14 19:08 nessai INFO    : it:  3000: Rolling KS test: D=0.003, p-value=0.9802
# 07-14 19:10 nessai INFO    : Checkpointing nested sampling
# 07-14 19:10 nessai INFO    : it:  3262: n eval: 27068 H: 10.17 dlogZ: 2987204.456 logZ: -3354277.358 +/- 0.101 logLmax: -367069.64
# 07-14 19:12 nessai INFO    : it:  3542: n eval: 32919 H: 10.45 dlogZ: 2877255.346 logZ: -3232214.666 +/- 0.102 logLmax: -354955.78
# 07-14 19:15 nessai INFO    : it:  3780: n eval: 39870 H: 10.68 dlogZ: 2766917.712 logZ: -3121877.270 +/- 0.103 logLmax: -354955.78
# 07-14 19:15 nessai INFO    : it:  4000: Rolling KS test: D=0.015, p-value=0.6313
# 07-14 19:18 nessai INFO    : it:  4008: n eval: 47567 H: 10.92 dlogZ: 2654992.580 logZ: -3009952.366 +/- 0.104 logLmax: -354955.78
# 07-14 19:22 nessai INFO    : Checkpointing nested sampling
# 07-14 19:22 nessai INFO    : it:  4203: n eval: 56097 H: 11.11 dlogZ: 2542301.775 logZ: -2897261.756 +/- 0.105 logLmax: -354955.78
# 07-14 19:26 nessai INFO    : it:  4386: n eval: 66097 H: 11.29 dlogZ: 2454161.255 logZ: -2809121.419 +/- 0.106 logLmax: -354955.78
# 07-14 19:30 nessai INFO    : it:  4572: n eval: 76097 H: 11.48 dlogZ: 2487174.387 logZ: -2697217.624 +/- 0.107 logLmax: -210038.67
# 07-15 01:03 nessai INFO    : Checkpointing nested sampling
# 07-15 01:03 nessai INFO    : it:  8823: n eval: 896097 H: 15.73 dlogZ: 514968.226 logZ: -583529.954 +/- 0.125 logLmax: -68552.91
# 07-15 01:07 nessai INFO    : it:  8860: n eval: 906097 H: 15.77 dlogZ: 505586.349 logZ: -574148.114 +/- 0.126 logLmax: -68552.91
# 07-15 01:11 nessai INFO    : it:  8916: n eval: 916097 H: 15.82 dlogZ: 496331.598 logZ: -564893.420 +/- 0.126 logLmax: -68552.91
# 07-15 01:15 nessai INFO    : Checkpointing nested sampling
# 07-15 01:15 nessai INFO    : it:  8955: n eval: 926097 H: 15.86 dlogZ: 487232.361 logZ: -555794.222 +/- 0.126 logLmax: -68552.91
# 07-15 01:19 nessai INFO    : it:  8997: n eval: 936097 H: 15.90 dlogZ: 477344.649 logZ: -545906.551 +/- 0.126 logLmax: -68552.91
# 07-15 01:19 nessai INFO    : it:  9000: Rolling KS test: D=0.04, p-value=0.03967
# 07-15 01:23 nessai INFO    : it:  9043: n eval: 946097 H: 15.95 dlogZ: 467566.830 logZ: -536128.778 +/- 0.126 logLmax: -68552.91
# 07-15 01:27 nessai INFO    : Checkpointing nested sampling
# 07-15 01:27 nessai INFO    : it:  9107: n eval: 956097 H: 16.01 dlogZ: 454842.054 logZ: -523404.067 +/- 0.127 logLmax: -68552.91
# 07-15 01:31 nessai INFO    : it:  9154: n eval: 966097 H: 16.06 dlogZ: 446094.270 logZ: -514656.329 +/- 0.127 logLmax: -68552.91
# 07-15 01:35 nessai INFO    : it:  9206: n eval: 976097 H: 16.11 dlogZ: 434830.857 logZ: -503392.968 +/- 0.127 logLmax: -68552.91
# 07-15 01:39 nessai INFO    : Checkpointing nested sampling
# 07-15 01:39 nessai INFO    : it:  9246: n eval: 986097 H: 16.15 dlogZ: 424228.474 logZ: -492790.626 +/- 0.127 logLmax: -68552.91
# 07-15 01:43 nessai INFO    : it:  9279: n eval: 996097 H: 16.19 dlogZ: 418408.542 logZ: -486970.726 +/- 0.127 logLmax: -68552.91
# 07-15 01:47 nessai INFO    : it:  9326: n eval: 1006097 H: 16.23 dlogZ: 408123.144 logZ: -476685.376 +/- 0.127 logLmax: -68552.91
# 07-15 01:51 nessai INFO    : Checkpointing nested sampling
# 07-15 01:51 nessai INFO    : it:  9369: n eval: 1016097 H: 16.28 dlogZ: 401980.785 logZ: -470543.060 +/- 0.128 logLmax: -68552.91
# 07-15 01:55 nessai INFO    : it:  9401: n eval: 1026097 H: 16.31 dlogZ: 395420.554 logZ: -463982.860 +/- 0.128 logLmax: -68552.91
# 07-15 01:59 nessai INFO    : it:  9450: n eval: 1036097 H: 16.36 dlogZ: 386517.891 logZ: -455080.247 +/- 0.128 logLmax: -68552.91
# 07-15 02:03 nessai INFO    : Checkpointing nested sampling
# 07-15 02:03 nessai INFO    : it:  9488: n eval: 1046097 H: 16.40 dlogZ: 380090.511 logZ: -448652.905 +/- 0.128 logLmax: -68552.91
# 07-15 05:26 nessai INFO    : it: 11231: n eval: 1546097 H: 18.13 dlogZ: 178389.865 logZ: -232285.667 +/- 0.135 logLmax: -53884.57
# 07-15 05:30 nessai INFO    : Checkpointing nested sampling
# 07-15 05:30 nessai INFO    : it: 11261: n eval: 1556097 H: 18.17 dlogZ: 175648.808 logZ: -229544.640 +/- 0.135 logLmax: -53884.57
# 07-15 05:34 nessai INFO    : it: 11291: n eval: 1566097 H: 18.20 dlogZ: 176074.027 logZ: -227035.768 +/- 0.135 logLmax: -50950.45
# 07-15 05:38 nessai INFO    : it: 11315: n eval: 1576097 H: 18.22 dlogZ: 174088.388 logZ: -225050.152 +/- 0.135 logLmax: -50950.45
# 07-15 05:42 nessai INFO    : Checkpointing nested sampling
# 07-15 05:42 nessai INFO    : it: 11350: n eval: 1586097 H: 18.09 dlogZ: 171184.500 logZ: -222146.299 +/- 0.134 logLmax: -50950.45
# 07-15 05:46 nessai INFO    : it: 11386: n eval: 1596097 H: 18.29 dlogZ: 168734.055 logZ: -219695.890 +/- 0.135 logLmax: -50950.45
# 07-15 05:50 nessai INFO    : it: 11411: n eval: 1606097 H: 18.32 dlogZ: 166283.598 logZ: -217245.459 +/- 0.135 logLmax: -50950.45
# 07-15 05:54 nessai INFO    : Checkpointing nested sampling
# 07-15 05:54 nessai INFO    : it: 11432: n eval: 1616097 H: 18.34 dlogZ: 164539.171 logZ: -215501.052 +/- 0.135 logLmax: -50950.45
# 07-15 05:58 nessai INFO    : it: 11452: n eval: 1626097 H: 18.36 dlogZ: 162865.858 logZ: -213827.759 +/- 0.135 logLmax: -50950.45
# 07-15 06:02 nessai INFO    : it: 11478: n eval: 1636097 H: 18.39 dlogZ: 161337.763 logZ: -212299.690 +/- 0.136 logLmax: -50950.45
# 07-15 06:06 nessai INFO    : Checkpointing nested sampling
# 07-15 06:06 nessai INFO    : it: 11503: n eval: 1646097 H: 18.34 dlogZ: 159470.537 logZ: -210432.490 +/- 0.135 logLmax: -50950.45
# 07-15 06:10 nessai INFO    : it: 11532: n eval: 1656097 H: 18.44 dlogZ: 157838.499 logZ: -208800.480 +/- 0.136 logLmax: -50950.45
# 07-15 06:14 nessai INFO    : it: 11558: n eval: 1666097 H: 18.47 dlogZ: 155750.477 logZ: -206712.484 +/- 0.136 logLmax: -50950.45
# 07-15 06:18 nessai INFO    : Checkpointing nested sampling
# 07-15 06:18 nessai INFO    : it: 11592: n eval: 1676097 H: 18.50 dlogZ: 153559.715 logZ: -204521.756 +/- 0.136 logLmax: -50950.45
# 07-15 06:22 nessai INFO    : it: 11617: n eval: 1686097 H: 18.52 dlogZ: 151761.317 logZ: -202723.383 +/- 0.136 logLmax: -50950.45
# 07-15 06:26 nessai INFO    : it: 11643: n eval: 1696097 H: 17.88 dlogZ: 149765.991 logZ: -200728.083 +/- 0.134 logLmax: -50950.45
# 07-15 06:30 nessai INFO    : Checkpointing nested sampling
# 07-15 06:30 nessai INFO    : it: 11675: n eval: 1706097 H: 18.58 dlogZ: 147801.548 logZ: -198763.672 +/- 0.136 logLmax: -50950.45
# 07-15 06:34 nessai INFO    : it: 11705: n eval: 1716097 H: 18.61 dlogZ: 145844.999 logZ: -196807.153 +/- 0.136 logLmax: -50950.45
# 07-15 06:38 nessai INFO    : it: 11735: n eval: 1726097 H: 18.53 dlogZ: 144262.668 logZ: -195224.852 +/- 0.136 logLmax: -50950.45
# 07-15 06:43 nessai INFO    : Checkpointing nested sampling
# 07-15 06:43 nessai INFO    : it: 11765: n eval: 1736097 H: 18.67 dlogZ: 142424.346 logZ: -193386.560 +/- 0.137 logLmax: -50950.45
# 07-15 06:47 nessai INFO    : it: 11797: n eval: 1746097 H: 18.70 dlogZ: 140125.161 logZ: -191087.408 +/- 0.137 logLmax: -50950.45
# 07-15 06:51 nessai INFO    : it: 11822: n eval: 1756097 H: 18.04 dlogZ: 138082.116 logZ: -189044.387 +/- 0.134 logLmax: -50950.45
# 07-15 06:55 nessai INFO    : Checkpointing nested sampling
# 07-15 06:55 nessai INFO    : it: 11848: n eval: 1766097 H: 18.76 dlogZ: 136043.111 logZ: -187005.408 +/- 0.137 logLmax: -50950.45
# 07-15 06:59 nessai INFO    : it: 11871: n eval: 1776097 H: 18.78 dlogZ: 134929.398 logZ: -185891.718 +/- 0.137 logLmax: -50950.45
# 07-15 07:03 nessai INFO    : it: 11897: n eval: 1786097 H: 18.80 dlogZ: 132998.949 logZ: -183961.295 +/- 0.137 logLmax: -50950.45
# 07-15 07:07 nessai INFO    : Checkpointing nested sampling
# 07-15 07:07 nessai INFO    : it: 11915: n eval: 1796097 H: 18.82 dlogZ: 132214.183 logZ: -183176.547 +/- 0.137 logLmax: -50950.45
# 07-15 07:11 nessai INFO    : it: 11935: n eval: 1806097 H: 18.84 dlogZ: 130802.291 logZ: -181764.675 +/- 0.137 logLmax: -50950.45
# 07-15 07:15 nessai INFO    : it: 11957: n eval: 1816097 H: 18.38 dlogZ: 129647.384 logZ: -180609.790 +/- 0.136 logLmax: -50950.45
# 07-15 07:19 nessai INFO    : Checkpointing nested sampling
# 07-15 07:19 nessai INFO    : it: 11984: n eval: 1826097 H: 18.89 dlogZ: 128646.333 logZ: -179608.766 +/- 0.137 logLmax: -50950.45
# 07-15 07:19 nessai INFO    : it: 12000: Rolling KS test: D=0.017, p-value=0.5547
# 07-15 07:23 nessai INFO    : it: 12006: n eval: 1836097 H: 18.91 dlogZ: 127437.248 logZ: -178399.703 +/- 0.138 logLmax: -50950.45
# 07-15 07:27 nessai INFO    : it: 12028: n eval: 1846097 H: 18.94 dlogZ: 125442.058 logZ: -176404.535 +/- 0.138 logLmax: -50950.45
# 07-15 07:31 nessai INFO    : Checkpointing nested sampling
# 07-15 07:31 nessai INFO    : it: 12053: n eval: 1856097 H: 18.96 dlogZ: 124034.697 logZ: -174997.199 +/- 0.138 logLmax: -50950.45
# 07-15 07:35 nessai INFO    : it: 12082: n eval: 1866097 H: 18.99 dlogZ: 122651.692 logZ: -173614.223 +/- 0.138 logLmax: -50950.45
# 07-15 07:39 nessai INFO    : it: 12111: n eval: 1876097 H: 19.02 dlogZ: 121243.025 logZ: -172205.585 +/- 0.138 logLmax: -50950.45
# 07-15 07:43 nessai INFO    : Checkpointing nested sampling
# 07-15 07:43 nessai INFO    : it: 12129: n eval: 1886097 H: 19.04 dlogZ: 119722.808 logZ: -170685.387 +/- 0.138 logLmax: -50950.45
# 07-15 07:47 nessai INFO    : it: 12155: n eval: 1896097 H: 19.06 dlogZ: 118248.530 logZ: -169211.134 +/- 0.138 logLmax: -50950.45
# 07-15 07:51 nessai INFO    : it: 12181: n eval: 1906097 H: 19.09 dlogZ: 117159.661 logZ: -168122.291 +/- 0.138 logLmax: -50950.45
# 07-15 07:56 nessai INFO    : Checkpointing nested sampling
# 07-15 07:56 nessai INFO    : it: 12205: n eval: 1916097 H: 19.11 dlogZ: 116087.204 logZ: -167049.858 +/- 0.138 logLmax: -50950.45
# 07-15 08:00 nessai INFO    : it: 12236: n eval: 1926097 H: 19.14 dlogZ: 114479.124 logZ: -165441.809 +/- 0.138 logLmax: -50950.45
# 07-15 08:04 nessai INFO    : it: 12255: n eval: 1936097 H: 19.16 dlogZ: 113413.230 logZ: -164375.934 +/- 0.138 logLmax: -50950.45
# 07-15 08:08 nessai INFO    : Checkpointing nested sampling
# 07-15 08:08 nessai INFO    : it: 12287: n eval: 1946097 H: 19.19 dlogZ: 111818.191 logZ: -162780.927 +/- 0.139 logLmax: -50950.45
# 07-15 08:12 nessai INFO    : it: 12317: n eval: 1956097 H: 19.21 dlogZ: 110506.658 logZ: -161469.424 +/- 0.139 logLmax: -50950.45
# 07-15 08:16 nessai INFO    : it: 12336: n eval: 1966097 H: 19.24 dlogZ: 109701.554 logZ: -160664.339 +/- 0.139 logLmax: -50950.45
# 07-15 08:20 nessai INFO    : Checkpointing nested sampling
# 07-15 08:20 nessai INFO    : it: 12359: n eval: 1976097 H: 19.25 dlogZ: 108804.499 logZ: -159767.307 +/- 0.139 logLmax: -50950.45
# 07-15 08:24 nessai INFO    : it: 12380: n eval: 1986097 H: 19.07 dlogZ: 107815.063 logZ: -158777.892 +/- 0.138 logLmax: -50950.45
# 07-15 08:28 nessai INFO    : it: 12403: n eval: 1996097 H: 19.31 dlogZ: 106631.517 logZ: -157594.369 +/- 0.139 logLmax: -50950.45
# 07-15 08:32 nessai INFO    : Checkpointing nested sampling
# 07-15 08:32 nessai INFO    : it: 12427: n eval: 2006097 H: 19.11 dlogZ: 105578.919 logZ: -156541.795 +/- 0.138 logLmax: -50950.45
# 07-15 08:36 nessai INFO    : it: 12447: n eval: 2016097 H: 19.35 dlogZ: 104751.832 logZ: -155714.729 +/- 0.139 logLmax: -50950.45
# 07-15 08:40 nessai INFO    : it: 12469: n eval: 2026097 H: 19.38 dlogZ: 103965.944 logZ: -154928.863 +/- 0.139 logLmax: -50950.45
# 07-15 08:44 nessai INFO    : Checkpointing nested sampling
# 07-15 09:53 nessai INFO    : it: 12884: n eval: 2206097 H: 19.10 dlogZ: 87799.272 logZ: -138762.605 +/- 0.138 logLmax: -50950.45
# 07-15 09:57 nessai INFO    : Checkpointing nested sampling
# 07-15 09:57 nessai INFO    : it: 12904: n eval: 2216097 H: 19.81 dlogZ: 87166.765 logZ: -138130.118 +/- 0.141 logLmax: -50950.45
# 07-15 10:01 nessai INFO    : it: 12931: n eval: 2226097 H: 19.84 dlogZ: 86295.392 logZ: -137258.772 +/- 0.141 logLmax: -50950.45
# 07-15 10:06 nessai INFO    : it: 12952: n eval: 2236097 H: 19.86 dlogZ: 85279.202 logZ: -136242.604 +/- 0.141 logLmax: -50950.45
# 07-15 10:10 nessai INFO    : Checkpointing nested sampling
# 07-15 10:10 nessai INFO    : it: 12965: n eval: 2246097 H: 19.87 dlogZ: 84854.840 logZ: -135818.254 +/- 0.141 logLmax: -50950.45
# 07-15 10:14 nessai INFO    : it: 12988: n eval: 2256097 H: 19.89 dlogZ: 84199.546 logZ: -135162.984 +/- 0.141 logLmax: -50950.45
# 07-15 10:14 nessai INFO    : it: 13000: Rolling KS test: D=0.034, p-value=0.09683
# 07-15 10:18 nessai INFO    : it: 13009: n eval: 2266097 H: 19.92 dlogZ: 85427.574 logZ: -134390.674 +/- 0.141 logLmax: -48950.09
# 07-15 10:22 nessai INFO    : Checkpointing nested sampling
# 07-15 10:22 nessai INFO    : it: 13030: n eval: 2276097 H: 19.94 dlogZ: 84708.679 logZ: -133671.801 +/- 0.141 logLmax: -48950.09
# 07-15 10:26 nessai INFO    : it: 13051: n eval: 2286097 H: 19.95 dlogZ: 84009.427 logZ: -132972.569 +/- 0.141 logLmax: -48950.09
# 07-15 10:30 nessai INFO    : it: 13069: n eval: 2296097 H: 19.98 dlogZ: 83322.462 logZ: -132285.623 +/- 0.141 logLmax: -48950.09
# 07-15 10:34 nessai INFO    : Checkpointing nested sampling
# 07-15 10:34 nessai INFO    : it: 13091: n eval: 2306097 H: 19.99 dlogZ: 82483.787 logZ: -131446.969 +/- 0.141 logLmax: -48950.09
# 07-15 10:38 nessai INFO    : it: 13113: n eval: 2316097 H: 20.02 dlogZ: 81599.899 logZ: -130563.103 +/- 0.141 logLmax: -48950.09
# 07-15 10:42 nessai INFO    : it: 13133: n eval: 2326097 H: 20.04 dlogZ: 81143.839 logZ: -130107.063 +/- 0.142 logLmax: -48950.09
# 07-15 10:47 nessai INFO    : Checkpointing nested sampling
# 07-15 10:47 nessai INFO    : it: 13148: n eval: 2336097 H: 20.06 dlogZ: 80574.122 logZ: -129537.362 +/- 0.142 logLmax: -48950.09
# 07-15 10:51 nessai INFO    : it: 13171: n eval: 2346097 H: 20.08 dlogZ: 79949.968 logZ: -128913.231 +/- 0.142 logLmax: -48950.09
# 07-15 10:55 nessai INFO    : it: 13197: n eval: 2356097 H: 20.10 dlogZ: 78506.204 logZ: -127469.492 +/- 0.142 logLmax: -48950.09
# 07-15 10:59 nessai INFO    : Checkpointing nested sampling
# 07-15 10:59 nessai INFO    : it: 13212: n eval: 2366097 H: 20.12 dlogZ: 78087.209 logZ: -127050.513 +/- 0.142 logLmax: -48950.09
# 07-15 11:03 nessai INFO    : it: 13231: n eval: 2376097 H: 20.14 dlogZ: 77326.557 logZ: -126289.880 +/- 0.142 logLmax: -48950.09
# 07-15 11:07 nessai INFO    : it: 13259: n eval: 2386097 H: 19.53 dlogZ: 76421.097 logZ: -125384.448 +/- 0.140 logLmax: -48950.09
# 07-15 11:11 nessai INFO    : Checkpointing nested sampling
# 07-15 11:11 nessai INFO    : it: 13283: n eval: 2396097 H: 20.19 dlogZ: 76196.588 logZ: -124352.023 +/- 0.142 logLmax: -48142.15
# 07-15 11:15 nessai INFO    : it: 13310: n eval: 2406097 H: 20.22 dlogZ: 75590.925 logZ: -123746.387 +/- 0.142 logLmax: -48142.15
# 07-15 11:19 nessai INFO    : it: 13331: n eval: 2416097 H: 20.24 dlogZ: 75133.170 logZ: -123288.654 +/- 0.142 logLmax: -48142.15
# 07-15 11:23 nessai INFO    : Checkpointing nested sampling
# 07-15 11:23 nessai INFO    : it: 13351: n eval: 2426097 H: 20.26 dlogZ: 74639.864 logZ: -122795.367 +/- 0.142 logLmax: -48142.15
# 07-15 11:27 nessai INFO    : it: 13374: n eval: 2436097 H: 20.25 dlogZ: 73946.082 logZ: -122101.609 +/- 0.142 logLmax: -48142.15
# ...
# 07-16 06:08 nessai INFO    : it: 38779: n eval: 5174920 H: 39.51 dlogZ: 27.719 logZ: -42229.556 +/- 0.199 logLmax: -42163.06
# 07-16 06:12 nessai INFO    : Checkpointing nested sampling
# 07-16 06:12 nessai INFO    : it: 38859: n eval: 5184920 H: 39.59 dlogZ: 27.110 logZ: -42229.028 +/- 0.199 logLmax: -42163.06
# 07-16 06:16 nessai INFO    : it: 38925: n eval: 5194920 H: 39.64 dlogZ: 26.627 logZ: -42228.611 +/- 0.199 logLmax: -42163.06
# 07-16 06:20 nessai INFO    : it: 38976: n eval: 5204920 H: 39.68 dlogZ: 26.263 logZ: -42228.297 +/- 0.199 logLmax: -42163.06
# 07-16 06:20 nessai INFO    : it: 39000: Rolling KS test: D=0.049, p-value=0.007937
# 07-16 06:24 nessai INFO    : Checkpointing nested sampling
# 07-16 06:24 nessai INFO    : it: 39047: n eval: 5214920 H: 39.73 dlogZ: 25.759 logZ: -42227.864 +/- 0.199 logLmax: -42163.06
# 07-16 06:28 nessai INFO    : it: 39144: n eval: 5224920 H: 39.78 dlogZ: 25.095 logZ: -42227.298 +/- 0.199 logLmax: -42163.06
# 07-16 06:32 nessai INFO    : it: 39225: n eval: 5234920 H: 39.84 dlogZ: 24.553 logZ: -42226.836 +/- 0.200 logLmax: -42163.06
# 07-16 06:36 nessai INFO    : Checkpointing nested sampling
# 07-16 06:36 nessai INFO    : it: 39255: n eval: 5244920 H: 39.86 dlogZ: 24.351 logZ: -42226.665 +/- 0.200 logLmax: -42163.06
# 07-16 06:41 nessai INFO    : it: 39310: n eval: 5254920 H: 39.91 dlogZ: 23.981 logZ: -42226.350 +/- 0.200 logLmax: -42163.06
# 07-16 06:45 nessai INFO    : it: 39367: n eval: 5264920 H: 39.94 dlogZ: 23.616 logZ: -42226.042 +/- 0.200 logLmax: -42163.06
# 07-16 06:49 nessai INFO    : Checkpointing nested sampling
# 07-16 06:49 nessai INFO    : it: 39440: n eval: 5274920 H: 39.97 dlogZ: 23.167 logZ: -42225.666 +/- 0.200 logLmax: -42163.06
# 07-16 06:53 nessai INFO    : it: 39527: n eval: 5284920 H: 40.02 dlogZ: 22.642 logZ: -42225.228 +/- 0.200 logLmax: -42163.06
# 07-16 06:57 nessai INFO    : it: 39572: n eval: 5294920 H: 40.04 dlogZ: 22.383 logZ: -42225.014 +/- 0.200 logLmax: -42163.06
# 07-16 07:01 nessai INFO    : Checkpointing nested sampling
# 07-16 07:01 nessai INFO    : it: 39620: n eval: 5304920 H: 40.06 dlogZ: 22.104 logZ: -42224.783 +/- 0.200 logLmax: -42163.06
# 07-16 07:05 nessai INFO    : it: 39730: n eval: 5314920 H: 40.13 dlogZ: 21.473 logZ: -42224.262 +/- 0.200 logLmax: -42163.06
# 07-16 07:09 nessai INFO    : it: 39777: n eval: 5324920 H: 40.17 dlogZ: 21.201 logZ: -42224.037 +/- 0.200 logLmax: -42163.06
# 07-16 07:13 nessai INFO    : Checkpointing nested sampling
# 07-16 07:13 nessai INFO    : it: 39815: n eval: 5334920 H: 40.19 dlogZ: 20.990 logZ: -42223.864 +/- 0.200 logLmax: -42163.06
# 07-16 07:17 nessai INFO    : it: 39856: n eval: 5344920 H: 40.22 dlogZ: 20.761 logZ: -42223.676 +/- 0.201 logLmax: -42163.06
# 07-16 07:21 nessai INFO    : it: 39932: n eval: 5354920 H: 40.28 dlogZ: 20.337 logZ: -42223.328 +/- 0.201 logLmax: -42163.06
# 07-16 07:25 nessai INFO    : Checkpointing nested sampling
# 07-16 07:25 nessai INFO    : it: 39969: n eval: 5364920 H: 40.31 dlogZ: 20.134 logZ: -42223.162 +/- 0.201 logLmax: -42163.06
# 07-16 07:25 nessai INFO    : it: 40000: Rolling KS test: D=0.024, p-value=0.311
# 07-16 07:30 nessai INFO    : it: 40012: n eval: 5374920 H: 40.33 dlogZ: 19.905 logZ: -42222.975 +/- 0.201 logLmax: -42163.06
# 07-16 07:34 nessai INFO    : it: 40053: n eval: 5384920 H: 40.36 dlogZ: 19.689 logZ: -42222.801 +/- 0.201 logLmax: -42163.06
# 07-16 07:38 nessai INFO    : Checkpointing nested sampling
# 07-16 07:38 nessai INFO    : it: 40116: n eval: 5394920 H: 40.40 dlogZ: 19.357 logZ: -42222.532 +/- 0.201 logLmax: -42163.06
# 07-16 07:42 nessai INFO    : it: 40148: n eval: 5404920 H: 40.43 dlogZ: 19.186 logZ: -42222.392 +/- 0.201 logLmax: -42163.06
# 07-16 07:46 nessai INFO    : it: 40200: n eval: 5414920 H: 40.46 dlogZ: 18.921 logZ: -42222.180 +/- 0.201 logLmax: -42163.06
# 07-16 07:50 nessai INFO    : Checkpointing nested sampling
# 07-16 07:50 nessai INFO    : it: 40253: n eval: 5424920 H: 40.49 dlogZ: 18.653 logZ: -42221.965 +/- 0.201 logLmax: -42163.06
# 07-16 07:54 nessai INFO    : it: 40331: n eval: 5434920 H: 40.56 dlogZ: 18.247 logZ: -42221.637 +/- 0.201 logLmax: -42163.06
# 07-16 07:58 nessai INFO    : it: 40425: n eval: 5444920 H: 40.61 dlogZ: 17.792 logZ: -42221.276 +/- 0.202 logLmax: -42163.06
# 07-16 08:02 nessai INFO    : Checkpointing nested sampling
# 07-16 08:02 nessai INFO    : it: 40486: n eval: 5454920 H: 40.64 dlogZ: 17.504 logZ: -42221.049 +/- 0.202 logLmax: -42163.06
# 07-16 08:06 nessai INFO    : it: 40522: n eval: 5464920 H: 40.66 dlogZ: 17.334 logZ: -42220.915 +/- 0.202 logLmax: -42163.06
# 07-16 08:10 nessai INFO    : it: 40554: n eval: 5474920 H: 40.69 dlogZ: 17.178 logZ: -42220.791 +/- 0.202 logLmax: -42163.06
# 07-16 08:15 nessai INFO    : Checkpointing nested sampling
# 07-16 08:15 nessai INFO    : it: 40581: n eval: 5484920 H: 40.71 dlogZ: 17.045 logZ: -42220.685 +/- 0.202 logLmax: -42163.06
# 07-16 08:19 nessai INFO    : it: 40655: n eval: 5494920 H: 40.78 dlogZ: 16.682 logZ: -42220.396 +/- 0.202 logLmax: -42163.06
# 07-16 08:23 nessai INFO    : it: 40719: n eval: 5504920 H: 40.84 dlogZ: 16.374 logZ: -42220.151 +/- 0.202 logLmax: -42163.06
# 07-16 08:27 nessai INFO    : Checkpointing nested sampling
# 07-16 08:27 nessai INFO    : it: 40743: n eval: 5514920 H: 40.86 dlogZ: 16.258 logZ: -42220.060 +/- 0.202 logLmax: -42163.06
# 07-16 08:31 nessai INFO    : it: 40787: n eval: 5524920 H: 40.90 dlogZ: 16.045 logZ: -42219.891 +/- 0.202 logLmax: -42163.06
# 07-16 08:35 nessai INFO    : it: 40811: n eval: 5534920 H: 40.92 dlogZ: 15.930 logZ: -42219.799 +/- 0.202 logLmax: -42163.06
# 07-16 08:39 nessai INFO    : Checkpointing nested sampling
# 07-16 08:39 nessai INFO    : it: 40843: n eval: 5544920 H: 40.95 dlogZ: 15.775 logZ: -42219.677 +/- 0.202 logLmax: -42163.06
# 07-16 08:43 nessai INFO    : it: 40868: n eval: 5554920 H: 40.97 dlogZ: 15.654 logZ: -42219.581 +/- 0.202 logLmax: -42163.06
# 07-16 08:47 nessai INFO    : it: 40896: n eval: 5564920 H: 41.00 dlogZ: 15.519 logZ: -42219.474 +/- 0.202 logLmax: -42163.06
# 07-16 08:51 nessai INFO    : Checkpointing nested sampling
# 07-16 08:51 nessai INFO    : it: 40917: n eval: 5574920 H: 41.01 dlogZ: 15.421 logZ: -42219.397 +/- 0.203 logLmax: -42163.06
# 07-16 08:55 nessai INFO    : it: 40947: n eval: 5584920 H: 41.03 dlogZ: 15.281 logZ: -42219.287 +/- 0.203 logLmax: -42163.06
# 07-16 08:59 nessai INFO    : it: 40973: n eval: 5594920 H: 41.05 dlogZ: 15.162 logZ: -42219.194 +/- 0.203 logLmax: -42163.06
# 07-16 09:04 nessai INFO    : Checkpointing nested sampling
# 07-16 09:04 nessai INFO    : it: 40994: n eval: 5604920 H: 41.07 dlogZ: 15.065 logZ: -42219.118 +/- 0.203 logLmax: -42163.06
# 07-16 09:04 nessai INFO    : it: 41000: Rolling KS test: D=0.031, p-value=0.1433
# 07-16 09:08 nessai INFO    : it: 41077: n eval: 5614920 H: 41.12 dlogZ: 14.695 logZ: -42218.831 +/- 0.203 logLmax: -42163.06
# 07-16 09:12 nessai INFO    : it: 41135: n eval: 5624920 H: 41.16 dlogZ: 14.440 logZ: -42218.634 +/- 0.203 logLmax: -42163.06
# 07-16 09:16 nessai INFO    : Checkpointing nested sampling
# 07-16 09:16 nessai INFO    : it: 41192: n eval: 5634920 H: 41.20 dlogZ: 14.190 logZ: -42218.441 +/- 0.203 logLmax: -42163.06
# 07-16 09:20 nessai INFO    : it: 41229: n eval: 5644920 H: 41.23 dlogZ: 14.026 logZ: -42218.314 +/- 0.203 logLmax: -42163.06
# 07-16 09:24 nessai INFO    : it: 41288: n eval: 5654920 H: 41.27 dlogZ: 13.771 logZ: -42218.118 +/- 0.203 logLmax: -42163.06
# 07-16 09:28 nessai INFO    : Checkpointing nested sampling
# 07-16 09:28 nessai INFO    : it: 41359: n eval: 5664920 H: 41.31 dlogZ: 13.786 logZ: -42217.891 +/- 0.203 logLmax: -42162.75
# 07-16 09:32 nessai INFO    : it: 41418: n eval: 5674920 H: 41.35 dlogZ: 13.541 logZ: -42217.704 +/- 0.203 logLmax: -42162.75
# 07-16 09:36 nessai INFO    : it: 41469: n eval: 5684920 H: 41.39 dlogZ: 13.329 logZ: -42217.544 +/- 0.203 logLmax: -42162.75
# 07-16 09:40 nessai INFO    : Checkpointing nested sampling
# 07-16 09:40 nessai INFO    : it: 41531: n eval: 5694920 H: 41.44 dlogZ: 13.069 logZ: -42217.345 +/- 0.204 logLmax: -42162.75
# 07-16 09:44 nessai INFO    : it: 41611: n eval: 5704920 H: 41.50 dlogZ: 12.736 logZ: -42217.093 +/- 0.204 logLmax: -42162.75
# 07-16 09:48 nessai INFO    : it: 41657: n eval: 5714920 H: 41.53 dlogZ: 12.548 logZ: -42216.951 +/- 0.204 logLmax: -42162.75
# 07-16 09:52 nessai INFO    : Checkpointing nested sampling
# 07-16 09:52 nessai INFO    : it: 41699: n eval: 5724920 H: 41.57 dlogZ: 12.378 logZ: -42216.822 +/- 0.204 logLmax: -42162.75
# 07-16 09:57 nessai INFO    : it: 41737: n eval: 5734920 H: 41.60 dlogZ: 12.224 logZ: -42216.707 +/- 0.204 logLmax: -42162.75
# 07-16 10:01 nessai INFO    : it: 41768: n eval: 5744920 H: 41.62 dlogZ: 12.101 logZ: -42216.614 +/- 0.204 logLmax: -42162.75
# 07-16 10:05 nessai INFO    : Checkpointing nested sampling
# 07-16 10:05 nessai INFO    : it: 41796: n eval: 5754920 H: 41.64 dlogZ: 11.988 logZ: -42216.530 +/- 0.204 logLmax: -42162.75
# 07-16 10:09 nessai INFO    : it: 41824: n eval: 5764920 H: 41.66 dlogZ: 11.878 logZ: -42216.447 +/- 0.204 logLmax: -42162.75
# 07-16 10:13 nessai INFO    : it: 41845: n eval: 5774920 H: 41.67 dlogZ: 11.797 logZ: -42216.387 +/- 0.204 logLmax: -42162.75
# 07-16 10:17 nessai INFO    : Checkpointing nested sampling
# 07-16 10:17 nessai INFO    : it: 41885: n eval: 5784920 H: 41.70 dlogZ: 11.645 logZ: -42216.275 +/- 0.204 logLmax: -42162.75
# 07-16 10:21 nessai INFO    : it: 41904: n eval: 5794920 H: 41.71 dlogZ: 11.573 logZ: -42216.222 +/- 0.204 logLmax: -42162.75
# 07-16 10:25 nessai INFO    : it: 41931: n eval: 5804920 H: 41.72 dlogZ: 11.472 logZ: -42216.148 +/- 0.204 logLmax: -42162.75
# 07-16 10:29 nessai INFO    : Checkpointing nested sampling
# 07-16 10:29 nessai INFO    : it: 41964: n eval: 5814920 H: 41.74 dlogZ: 11.350 logZ: -42216.060 +/- 0.204 logLmax: -42162.75
# 07-16 10:33 nessai INFO    : it: 42000: Rolling KS test: D=0.021, p-value=0.4082
# 07-16 10:33 nessai INFO    : it: 42000: n eval: 5824920 H: 41.76 dlogZ: 11.219 logZ: -42215.965 +/- 0.204 logLmax: -42162.75
# 07-16 10:37 nessai INFO    : it: 42036: n eval: 5834920 H: 41.78 dlogZ: 11.090 logZ: -42215.871 +/- 0.204 logLmax: -42162.75
# 07-16 10:41 nessai INFO    : Checkpointing nested sampling
# 07-16 10:41 nessai INFO    : it: 42059: n eval: 5844920 H: 41.79 dlogZ: 11.375 logZ: -42215.812 +/- 0.204 logLmax: -42162.38
# 07-16 10:46 nessai INFO    : it: 42084: n eval: 5854920 H: 41.80 dlogZ: 11.285 logZ: -42215.748 +/- 0.204 logLmax: -42162.38
# 07-16 10:50 nessai INFO    : it: 42120: n eval: 5864920 H: 41.82 dlogZ: 11.211 logZ: -42215.658 +/- 0.205 logLmax: -42162.33
# 07-16 10:54 nessai INFO    : Checkpointing nested sampling
# 07-16 10:54 nessai INFO    : it: 42157: n eval: 5874920 H: 41.84 dlogZ: 11.081 logZ: -42215.565 +/- 0.205 logLmax: -42162.33
# 07-16 10:58 nessai INFO    : it: 42200: n eval: 5884920 H: 41.87 dlogZ: 10.933 logZ: -42215.459 +/- 0.205 logLmax: -42162.33
# 07-16 11:02 nessai INFO    : it: 42245: n eval: 5894920 H: 41.89 dlogZ: 10.780 logZ: -42215.352 +/- 0.205 logLmax: -42162.33
# 07-16 11:06 nessai INFO    : Checkpointing nested sampling
# 07-16 11:06 nessai INFO    : it: 42278: n eval: 5904920 H: 41.91 dlogZ: 10.668 logZ: -42215.273 +/- 0.205 logLmax: -42162.33
# 07-16 11:10 nessai INFO    : it: 42314: n eval: 5914920 H: 41.93 dlogZ: 10.545 logZ: -42215.185 +/- 0.205 logLmax: -42162.33
# 07-16 11:14 nessai INFO    : it: 42343: n eval: 5924920 H: 41.95 dlogZ: 10.446 logZ: -42215.116 +/- 0.205 logLmax: -42162.33
# 07-16 11:18 nessai INFO    : Checkpointing nested sampling
# 07-16 11:18 nessai INFO    : it: 42369: n eval: 5934920 H: 41.97 dlogZ: 10.690 logZ: -42215.055 +/- 0.205 logLmax: -42162.00
# 07-16 11:22 nessai INFO    : it: 42416: n eval: 5944920 H: 41.99 dlogZ: 10.537 logZ: -42214.949 +/- 0.205 logLmax: -42162.00
# 07-16 11:26 nessai INFO    : it: 42449: n eval: 5954920 H: 42.01 dlogZ: 10.463 logZ: -42214.874 +/- 0.205 logLmax: -42161.96
# 07-16 11:30 nessai INFO    : Checkpointing nested sampling
# 07-16 11:30 nessai INFO    : it: 42473: n eval: 5964920 H: 42.02 dlogZ: 10.385 logZ: -42214.821 +/- 0.205 logLmax: -42161.96
# 07-16 11:35 nessai INFO    : it: 42505: n eval: 5974920 H: 42.04 dlogZ: 10.330 logZ: -42214.751 +/- 0.205 logLmax: -42161.92
# 07-16 11:39 nessai INFO    : it: 42522: n eval: 5984920 H: 42.05 dlogZ: 10.276 logZ: -42214.714 +/- 0.205 logLmax: -42161.92
# 07-16 11:43 nessai INFO    : Checkpointing nested sampling
# 07-16 11:43 nessai INFO    : it: 42547: n eval: 5994920 H: 42.06 dlogZ: 10.198 logZ: -42214.660 +/- 0.205 logLmax: -42161.92
# 07-16 11:47 nessai INFO    : it: 42585: n eval: 6004920 H: 42.08 dlogZ: 10.078 logZ: -42214.578 +/- 0.205 logLmax: -42161.92
# 07-16 11:51 nessai INFO    : it: 42617: n eval: 6014920 H: 42.10 dlogZ: 9.976 logZ: -42214.509 +/- 0.205 logLmax: -42161.92
# 07-16 11:55 nessai INFO    : Checkpointing nested sampling
# 07-16 11:55 nessai INFO    : it: 42650: n eval: 6024920 H: 42.12 dlogZ: 9.873 logZ: -42214.438 +/- 0.205 logLmax: -42161.92
# 07-16 11:59 nessai INFO    : it: 42689: n eval: 6034920 H: 42.14 dlogZ: 9.752 logZ: -42214.357 +/- 0.205 logLmax: -42161.92
# 07-16 12:03 nessai INFO    : it: 42728: n eval: 6044920 H: 42.17 dlogZ: 9.633 logZ: -42214.276 +/- 0.205 logLmax: -42161.92
# 07-16 12:07 nessai INFO    : Checkpointing nested sampling
# 07-16 12:07 nessai INFO    : it: 42767: n eval: 6054920 H: 42.19 dlogZ: 9.513 logZ: -42214.196 +/- 0.205 logLmax: -42161.92
# 07-16 12:11 nessai INFO    : it: 42798: n eval: 6064920 H: 42.21 dlogZ: 9.419 logZ: -42214.133 +/- 0.205 logLmax: -42161.92
# 07-16 12:15 nessai INFO    : it: 42820: n eval: 6074920 H: 42.22 dlogZ: 9.353 logZ: -42214.088 +/- 0.205 logLmax: -42161.92
# 07-16 12:19 nessai INFO    : Checkpointing nested sampling
# 07-16 12:19 nessai INFO    : it: 42838: n eval: 6084920 H: 42.23 dlogZ: 10.499 logZ: -42214.052 +/- 0.206 logLmax: -42160.72
# 07-16 12:23 nessai INFO    : it: 42857: n eval: 6094920 H: 42.25 dlogZ: 10.442 logZ: -42214.013 +/- 0.206 logLmax: -42160.72
# 07-16 12:28 nessai INFO    : it: 42923: n eval: 6104920 H: 42.29 dlogZ: 10.313 logZ: -42213.882 +/- 0.206 logLmax: -42160.65
# 07-16 12:32 nessai INFO    : Checkpointing nested sampling
# 07-16 12:32 nessai INFO    : it: 42958: n eval: 6114920 H: 42.31 dlogZ: 10.211 logZ: -42213.814 +/- 0.206 logLmax: -42160.65
# 07-16 12:36 nessai INFO    : it: 42988: n eval: 6124920 H: 42.32 dlogZ: 10.123 logZ: -42213.757 +/- 0.206 logLmax: -42160.65
# 07-16 12:36 nessai INFO    : it: 43000: Rolling KS test: D=0.039, p-value=0.0465
# 07-16 12:40 nessai INFO    : it: 43043: n eval: 6134920 H: 42.36 dlogZ: 9.964 logZ: -42213.653 +/- 0.206 logLmax: -42160.65
# 07-16 12:44 nessai INFO    : Checkpointing nested sampling
# 07-16 12:44 nessai INFO    : it: 43068: n eval: 6144920 H: 42.37 dlogZ: 9.892 logZ: -42213.605 +/- 0.206 logLmax: -42160.65
# 07-16 12:48 nessai INFO    : it: 43134: n eval: 6154920 H: 42.41 dlogZ: 9.702 logZ: -42213.481 +/- 0.206 logLmax: -42160.65
# 07-16 12:52 nessai INFO    : it: 43203: n eval: 6164920 H: 42.46 dlogZ: 9.503 logZ: -42213.351 +/- 0.206 logLmax: -42160.65
# 07-16 12:56 nessai INFO    : Checkpointing nested sampling
# 07-16 12:56 nessai INFO    : it: 43230: n eval: 6174920 H: 42.48 dlogZ: 9.426 logZ: -42213.302 +/- 0.206 logLmax: -42160.65
# 07-16 13:00 nessai INFO    : it: 43266: n eval: 6184920 H: 42.50 dlogZ: 9.324 logZ: -42213.236 +/- 0.206 logLmax: -42160.65
# 07-16 13:04 nessai INFO    : it: 43301: n eval: 6194920 H: 42.53 dlogZ: 9.225 logZ: -42213.172 +/- 0.206 logLmax: -42160.65
# 07-16 13:08 nessai INFO    : Checkpointing nested sampling
# 07-16 13:08 nessai INFO    : it: 43331: n eval: 6204920 H: 42.55 dlogZ: 9.141 logZ: -42213.118 +/- 0.206 logLmax: -42160.65
# 07-16 13:12 nessai INFO    : it: 43374: n eval: 6214920 H: 42.58 dlogZ: 9.021 logZ: -42213.041 +/- 0.206 logLmax: -42160.65
# 07-16 13:17 nessai INFO    : it: 43429: n eval: 6224920 H: 42.61 dlogZ: 8.870 logZ: -42212.945 +/- 0.206 logLmax: -42160.65
# 07-16 13:21 nessai INFO    : Checkpointing nested sampling
# 07-16 13:21 nessai INFO    : it: 43485: n eval: 6234920 H: 42.64 dlogZ: 8.719 logZ: -42212.850 +/- 0.207 logLmax: -42160.65

# %%
# Make a corner plot.
result.plot_corner(save=True)
