# %%
# limit the thread used by numpy 
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"  

import numpy as np
from tqdm import tqdm
import matplotlib.pyplot as plt

# import matplotlib
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.family'] = 'serif'

from Triangle.Constants import *
from Triangle.Orbit import * 
from Triangle.Noise import *
from Triangle.FFTTools import *
from Triangle.Data import * 
from Triangle.Cosmology import * 

from Triangle_BBH.Waveform import * 
from Triangle_BBH.Response import *
from Triangle_BBH.Utils import *
from Triangle_BBH.Fisher import *

np.random.seed(114514)
# Out:
# PyCBC.libutils: pkg-config call failed, setting NO_PKGCONFIG=1
# has cupy
# has cupy
# has BBHx waveform

# %% [markdown]
# ## Mission settings

# %%
MISSION = "Taiji"
if MISSION == "Taiji": 
    nominal_arm = 3e9 
    acc_noise_budget = 3e-15 
    oms_noise_budget = 8e-12 
    orbit_dir = "../../Triangle-Simulator/OrbitData/MicroSateOrbitEclipticTCB"
    orbit_dt = DAY 
elif MISSION == "LISA": 
    pass

# %% [markdown]
# ## Data settings

# %%
Tobs = 15. * DAY # data length in s 
t_start = 0. * DAY # start time in s
t_end = t_start + Tobs # end time in s 
dt = 20. # time cadance in s 
data_frequencies_full = np.fft.rfftfreq(n=int(Tobs/dt), d=dt) # frequecies where waveform will be calculated 
Tobs = int(Tobs/dt) * dt 
delta_f = 1. / Tobs

# mask the "null" frequencies, which may cause singularity in the calculation of likelihood 
mask = np.ones_like(data_frequencies_full, dtype=bool)
for i in range(1, 50): 
    mask_idx = np.where(np.abs(data_frequencies_full - i*C/4./nominal_arm)<i*3e-4)[0] # the 0.3mHz window is an empirical value
    mask[mask_idx] = False 

# remove the frequencies below sensitive band 
mask_idx = np.where(data_frequencies_full < 1e-5)[0]
mask[mask_idx] = False 

data_frequencies = data_frequencies_full[mask]

data_frequencies.shape, data_frequencies_full.shape
# Out:
# ((31976,), (32401,))

# %% [markdown]
# ## Model settings

# %% [markdown]
# ### Orbit model

# %%
orbit = Orbit(
    OrbitDir=orbit_dir, 
    dt=orbit_dt, 
)

# %% [markdown]
# ### Waveform model

# %%
WFG = WaveformGeneratorFRef(
    mode="primary", # "primary" for 22 mode only 
)

# %% [markdown]
# ### TDI Response model and settings

# %%
FDTDI = FDTDIResponseGeneratorFRef(
    orbit_class=orbit, 
    waveform_generator=WFG, 
)

response_kwargs = dict(
    fmin=data_frequencies[-1], # used to calculate freq grid
    fmax=data_frequencies[0], # used to calculate freq grid
    fref=1e-3, # used to set reference point 
    Nfreqs=1024, # used to calculate freq grid
    modes=[(2, 2)], 
    tmin=t_start/DAY, # minimum time of orbit in day 
    tmax=t_end/DAY, # maximum time of orbit in day
    tref_at_constellation=True, # whether tref is the defined at detector center (True) or SSB (False)
    TDIGeneration='2nd',
    optimal_combination=True, # True for AET, False for XYZ 
)

# %% [markdown]
# ### Noise model

# %%
# set detector noise model 
PSDfunc = TDIPSDs(
    sacc=acc_noise_budget, 
    sro=oms_noise_budget, 
    L=nominal_arm, 
) 

# average over observation times to get noise CSD 
psd_a = np.zeros_like(data_frequencies)
psd_e = np.zeros_like(data_frequencies)
psd_t = np.zeros_like(data_frequencies)
noise_times = np.linspace(t_start, t_end, int(Tobs/DAY))
for itime in tqdm(range(len(noise_times))):
    arms = dict()
    for key in MOSA_labels: 
        arms[key] = orbit.LTTfunctions()[key](noise_times[itime])
    psd_a += PSDfunc.PSD_A2_unequal(data_frequencies, arms)
    psd_e += PSDfunc.PSD_E2_unequal(data_frequencies, arms)
    psd_t += PSDfunc.PSD_T2_unequal(data_frequencies, arms)
psd_a *= 1. / len(noise_times)
psd_e *= 1. / len(noise_times)
psd_t *= 1. / len(noise_times)
psd_channels = np.array([psd_a, psd_e, psd_t])

# noise-othorgonal approximation
csd_ae = np.zeros_like(psd_a)
csd_et = np.zeros_like(psd_a)
csd_ta = np.zeros_like(psd_a)

# noise orthogonal assumption 
covmatrix = np.array([
    [psd_a, csd_ae, np.conjugate(csd_ta)], 
    [np.conjugate(csd_ae), psd_e, csd_et], 
    [csd_ta, np.conjugate(csd_et), psd_t],
]) / 4. / delta_f # (3, 3, Nf)

inv_covmatrix = np.linalg.inv(np.transpose(covmatrix, axes=(2, 0, 1))) # (Nf, 3, 3)
# set the 3-3 element to 0 so that T channel will not be used in likelihood calculation
inv_covmatrix[:, 2, 2] *= 0.
# Out:
# 100%|██████████| 15/15 [00:00<00:00, 21.50it/s]

# %% [markdown]
# ## Data Generation

# %%
mbhb_parameters = {
    'chirp_mass': 1527693.2821010326, # solar mass, redshifted 
    'mass_ratio': 0.6060083963754411,
    'spin_1z': 0., # fix spin=0 for this example 
    'spin_2z': 0.,
    'reference_time': 10.927959071370836, # day 
    'reference_phase': 2.1563629722527997, # rad 
    'luminosity_distance': 22016.264842325963, # mpc 
    'inclination': 1.9340646499796517, # rad 
    'longitude': 3.279277442759269, # rad, ecliptic 
    'latitude': 0.9176152704924524, # rad, ecliptic 
    'psi': 1.988850127130235 # rad 
    }

data_channels = FDTDI.Response(
    mbhb_parameters, 
    data_frequencies, 
    **response_kwargs, 
)

snr = FrequencyDomainCovarianceSNR(data_channels, inv_covmatrix)
print("signal-to-noise ratio is", snr)
# Out:
# signal-to-noise ratio is 2297.0235111297243

# %%
tdi_names = ["A", "E", "T"]
tdi_colors = [RED, GREEN1, ORANGE]

for i in range(3): 
    plt.loglog(data_frequencies, np.abs(data_channels[i]) * 2. * data_frequencies, label="TDI "+tdi_names[i]+" channel, signal", color=tdi_colors[i])
    plt.loglog(data_frequencies, np.sqrt(psd_channels[i] * data_frequencies), label="TDI "+tdi_names[i]+" channel, noise", color=tdi_colors[i], linestyle="--")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Characteristic strain")
plt.legend(loc="upper left")

# %% [markdown]
# ## Fisher analysis

# %%
def fisher_waveform_wrapper(param_dict, frequencies):
    res = FDTDI.Response(
        param_dict, 
        frequencies,  
        **response_kwargs, 
    )
    return res

# set initial steps for FIM calculation 
analyze_param_step_dict = {
    'chirp_mass': 10.,
    'mass_ratio': 0.01,
    # 'spin_1z': 0.01,
    # 'spin_2z': 0.01,
    'reference_time': 0.01,
    'reference_phase': 0.01,
    'luminosity_distance': 100.,
    'inclination': 0.01,
    'longitude': 0.01,
    'latitude': 0.01,
    'psi': 0.01
    }
for k, v in analyze_param_step_dict.items():
    analyze_param_step_dict[k] = -v 

FIM = MultiChannelFisher(
    waveform_generator=fisher_waveform_wrapper, 
    param_dict=mbhb_parameters, 
    analyze_param_step_dict=analyze_param_step_dict, 
    frequency=data_frequencies, 
    inverse_covariance=inv_covmatrix,
    verbose=0
)
FIM.auto_test_step()
FIM.calculate_Fisher()
FIM.calculate_errors() 

FIM.param_errors
# Out:
# {'chirp_mass': 203.00674065916118,
#  'mass_ratio': 0.0006312965607773927,
#  'reference_time': 3.1505088192636264e-06,
#  'reference_phase': 0.031097083330334153,
#  'luminosity_distance': 1390.0991739398428,
#  'inclination': 0.017824197941592443,
#  'longitude': 0.04192646096330614,
#  'latitude': 0.022685821186194954,
#  'psi': 0.023170028261690453}

# %% [markdown]
# ## Parameter estimation with bilby

# %%
import bilby

# %% [markdown]
# ### prior

# %%
# set prior to be 10 sigma around the truths 
priors = bilby.core.prior.PriorDict()
priors["chirp_mass"] = bilby.prior.Uniform(minimum=mbhb_parameters["chirp_mass"]-10.*FIM.param_errors["chirp_mass"], maximum=mbhb_parameters["chirp_mass"]+10.*FIM.param_errors["chirp_mass"], name='chirp_mass', latex_label='$\mathcal{M}_c$')
priors["mass_ratio"] = bilby.prior.Uniform(minimum=max(0.1, mbhb_parameters["mass_ratio"]-10.*FIM.param_errors["mass_ratio"]), maximum=min(0.99, mbhb_parameters["mass_ratio"]+10.*FIM.param_errors["mass_ratio"]), name="mass_ratio", latex_label='$q$')
priors["spin_1z"] = bilby.prior.Uniform(minimum=-0.9, maximum=0.9, name="spin_1z", latex_label='$\chi_{z1}$')
priors["spin_2z"] = bilby.prior.Uniform(minimum=-0.9, maximum=0.9, name="spin_1z", latex_label='$\chi_{z2}$')
priors["reference_time"] = bilby.prior.Uniform(minimum=mbhb_parameters["reference_time"]-10.*FIM.param_errors["reference_time"], maximum=mbhb_parameters["reference_time"]+10.*FIM.param_errors["reference_time"], name="reference_time", latex_label='$t_\mathrm{ref}$') 
priors["reference_phase"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="reference_phase", latex_label='$\\varphi_\mathrm{ref}$', boundary="periodic")
priors["luminosity_distance"] = bilby.prior.Uniform(minimum=max(6e3, mbhb_parameters["luminosity_distance"]-10.*FIM.param_errors["luminosity_distance"]), maximum=min(1e5, mbhb_parameters["luminosity_distance"]+10.*FIM.param_errors["luminosity_distance"]), name="luminosity_distance", latex_label='$d_L$')
priors["inclination"] = bilby.prior.Sine(minimum=0., maximum=PI, name="inclination", latex_label='$\iota$')
priors["longitude"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="longitude", latex_label='$\lambda$', boundary="periodic")
priors["latitude"] = bilby.prior.Cosine(minimum=-PI/2., maximum=PI/2., name="latitude", latex_label='$\\beta$')
priors["psi"] = bilby.prior.Uniform(minimum=0., maximum=PI, name="psi", latex_label='$\psi$', boundary="periodic")

priors["spin_1z"] = 0. 
priors["spin_2z"] = 0.

# %% [markdown]
# ### Likelihood
# $${\rm ln} \mathcal{L}(\theta) = -\frac{1}{2}(d - h(\theta) | d - h(\theta))$$

# %%
class bilby_likelihood_wrapper(bilby.Likelihood):
    def __init__(self):
        super().__init__(
            parameters={
                'chirp_mass': None,
                'mass_ratio': None,
                'spin_1z': None,
                'spin_2z': None,
                'reference_time': None,
                'reference_phase': None,
                'luminosity_distance': None,
                'inclination': None,
                'longitude': None,
                'latitude': None,
                'psi': None
            }
        )

    def log_likelihood(self):
        temp_channels = FDTDI.Response(
            self.parameters, 
            data_frequencies, 
            **response_kwargs, 
        ) # (3, Nf)
        return -0.5 * FrequencyDomainCovarianceSNR(data_channels=temp_channels-data_channels, inv_cov=inv_covmatrix) ** 2

# %%
BLike = bilby_likelihood_wrapper()

import multiprocessing
ncpu = multiprocessing.cpu_count()
print("number of cpus =", ncpu)

result = bilby.run_sampler(
    likelihood=BLike, 
    priors=priors,
    sampler="nessai", 
    nlive=2000,
    # walks=20,
    # nact=50,
    # maxmcmc=2000,
    stopping=0.1, 
    npool=ncpu, # use all cpus 
    injection_parameters=mbhb_parameters, 
    outdir="../../Samples",
    label="tribbh_example",
    plot=True,
    resume=False, 
    # resume=True, 
)
# Out:
# 15:20 bilby INFO    : Running for label 'tribbh_example', output will be saved to '../../Samples'
# number of cpus = 32
# /home/ps/miniconda3/envs/tri_env/lib/python3.9/site-packages/bilby/core/utils/log.py:73: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   vdict[key] = str(getattr(sys.modules[key], "__version__", "N/A"))
# 15:20 bilby INFO    : Analysis priors:
# 15:20 bilby INFO    : chirp_mass=Uniform(minimum=1525663.2146944408, maximum=1529723.3495076243, name='chirp_mass', latex_label='$\\mathcal{M}_c$', unit=None, boundary=None)
# 15:20 bilby INFO    : mass_ratio=Uniform(minimum=0.5996954307676672, maximum=0.6123213619832151, name='mass_ratio', latex_label='$q$', unit=None, boundary=None)
# 15:20 bilby INFO    : reference_time=Uniform(minimum=10.927927566282643, maximum=10.92799057645903, name='reference_time', latex_label='$t_\\mathrm{ref}$', unit=None, boundary=None)
# 15:20 bilby INFO    : reference_phase=Uniform(minimum=0.0, maximum=6.283185307179586, name='reference_phase', latex_label='$\\varphi_\\mathrm{ref}$', unit=None, boundary='periodic')
# 15:20 bilby INFO    : luminosity_distance=Uniform(minimum=8115.273102927535, maximum=35917.25658172439, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None)
# 15:20 bilby INFO    : inclination=Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None)
# 15:20 bilby INFO    : longitude=Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic')
# 15:20 bilby INFO    : latitude=Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None)
# 15:20 bilby INFO    : psi=Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')
# 15:20 bilby INFO    : spin_1z=0.0
# 15:20 bilby INFO    : spin_2z=0.0
# 15:20 bilby INFO    : Analysis likelihood class: <class '__main__.bilby_likelihood_wrapper'>
# 15:20 bilby INFO    : Analysis likelihood noise evidence: nan
# 15:20 bilby INFO    : Single likelihood evaluation took nan s
# 15:20 bilby INFO    : Using sampler Nessai with kwargs {'n_steps': 10, 'n_accept': None, 'step_type': 'gaussian', 'step_kwargs': None, 'plot_chain': False, 'plot_history': False, 'enforce_likelihood_threshold': True, 'ensemble_fraction': 0.5, 'rng': None, 'flow_config': None, 'training_config': None, 'output': '../../Samples/tribbh_example_nessai/', 'poolsize': 1000, 'plot': True, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'max_n_clusters': None, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False, 'augment_dims': 1, 'generate_augment': 'gaussian', 'marginalise_augment': False, 'n_marg': 50, 'nlive': 2000, 'stopping': 0.1, 'max_iteration': None, 'checkpointing': True, 'checkpoint_interval': 600, 'checkpoint_on_iteration': False, 'checkpoint_on_training': False, 'checkpoint_callback': None, 'logging_interval': 60, 'log_on_iteration': False, 'resume_file': 'nested_sampler_resume.pkl', 'seed': None, 'pool': None, 'close_pool': None, 'n_pool': 32, 'proposal_plots': False, 'prior_sampling': False, 'analytic_priors': False, 'maximum_uninformed': None, 'uninformed_proposal': None, 'uninformed_acceptance_threshold': None, 'uninformed_proposal_kwargs': None, 'flow_proposal_class': None, 'flow_class': None, 'training_frequency': None, 'train_on_empty': True, 'cooldown': 200, 'memory': False, 'reset_weights': False, 'reset_permutations': False, 'reset_flow': False, 'retrain_acceptance': True, 'reset_acceptance': False, 'acceptance_threshold': 0.01, 'shrinkage_expectation': 'logt', 'trace_parameters': None, 'resume': False, 'resume_data': None, 'weights_file': None, 'weights_path': None, 'exit_code': 130, 'pytorch_threads': 1, 'eps': None, 'torch_dtype': None, 'disable_vectorisation': False, 'likelihood_chunksize': None, 'allow_multi_valued_likelihood': None, 'parallelise_prior': None, 'result_extension': 'hdf5', 'plot_indices': True, 'plot_posterior': False, 'plot_logXlogL': True, 'posterior_sampling_method': None, 'nessai_log_level': None, 'nessai_logging_stream': 'stdout', 'nessai_plot': True, 'nessai_likelihood_constraint': True}
# 09-23 15:20 nessai INFO    : Running Nessai version 0.14.0.post0
# 09-23 15:20 nessai INFO    : Starting multiprocessing pool with 32 processes
# /home/ps/miniconda3/envs/tri_env/lib/python3.9/site-packages/nessai/utils/logging.py:133: FutureWarning: setup_logger is deprecated, use configure_logger instead
#   warnings.warn(
# 09-23 15:20 nessai INFO    : Initialising nested sampler
# 09-23 15:20 nessai WARNING : Multiprocessing pool has already been configured.
# 09-23 15:20 nessai WARNING : Removing unused keyword arguments ({'plot_chain', 'n_steps', 'step_kwargs', 'enforce_likelihood_threshold', 'step_type', 'n_accept', 'augment_dims', 'ensemble_fraction', 'n_marg', 'marginalise_augment', 'plot_history', 'generate_augment', 'max_n_clusters'}) from kwargs for FlowProposal. These are valid keyword arguments but correspond to other proposal classes.
# 09-23 15:20 nessai INFO    : Passing kwargs to FlowProposal: {'training_config': None, 'poolsize': 1000, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False}
# 09-23 15:20 nessai WARNING : Signal handling is disabled. nessai will not automatically checkpoint when exited.
# 09-23 15:20 nessai INFO    : No reparameterisations provided, using default reparameterisations included in FlowProposal
# 09-23 15:20 nessai INFO    : Adding reparameterisations from: {}
# 09-23 15:20 nessai INFO    : Assuming fallback reparameterisation (ScaleAndShift) for ['chirp_mass', 'mass_ratio', 'reference_time', 'reference_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi'] with kwargs: {'estimate_scale': True, 'estimate_shift': True, 'prior_bounds': {'chirp_mass': array([1525663.21469444, 1529723.34950762]), 'mass_ratio': array([0.59969543, 0.61232136]), 'reference_time': array([10.92792757, 10.92799058]), 'reference_phase': array([0.        , 6.28318531]), 'luminosity_distance': array([ 8115.27310293, 35917.25658172]), 'inclination': array([0.        , 3.14159265]), 'longitude': array([0.        , 6.28318531]), 'latitude': array([-1.57079633,  1.57079633]), 'psi': array([0.        , 3.14159265])}}.
# 09-23 15:20 nessai INFO    : x space parameters: ['chirp_mass', 'mass_ratio', 'reference_time', 'reference_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# 09-23 15:20 nessai INFO    : x prime space parameters: ['chirp_mass_prime', 'mass_ratio_prime', 'reference_time_prime', 'reference_phase_prime', 'luminosity_distance_prime', 'inclination_prime', 'longitude_prime', 'latitude_prime', 'psi_prime']
# 09-23 15:20 nessai INFO    : Overwriting fuzz factor with expansion fraction
# 09-23 15:20 nessai INFO    : New fuzz factor: 1.195813174500402
# 09-23 15:20 nessai INFO    : Verifying rescaling functions
# 09-23 15:20 nessai INFO    : Rescaling functions are invertible
# 09-23 15:20 nessai INFO    : Populating initial live points
# 09-23 15:20 nessai INFO    : Populated 200 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 400 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 600 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 800 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 1000 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 1200 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 1400 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 1600 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 1800 / 2000 live points
# 09-23 15:20 nessai INFO    : Populated 2000 / 2000 live points
# 09-23 15:20 nessai INFO    : Starting nested sampling loop
# 09-23 15:20 nessai INFO    : it:  2000: Rolling KS test: D=0.0025, p-value=0.9737
# 09-23 15:21 nessai INFO    : it:  4000: Rolling KS test: D=0.0165, p-value=0.3329
# 09-23 15:21 nessai INFO    : Switching to FlowProposal
# 09-23 15:21 nessai INFO    : it:  4764: n eval: 24213 H: 9.98 dlogZ: 2155067.005 logZ: -2194310.140 +/- 0.071 logLmax: -39240.75
# 09-23 15:22 nessai INFO    : it:  6000: Rolling KS test: D=0.016, p-value=0.3554
# 09-23 15:22 nessai INFO    : it:  6974: n eval: 59587 H: 11.09 dlogZ: 1144931.148 logZ: -1177106.776 +/- 0.074 logLmax: -32172.14
# 09-23 15:23 nessai INFO    : it:  8000: Rolling KS test: D=0.0235, p-value=0.1081
# 09-23 15:24 nessai INFO    : it:  8288: n eval: 99114 H: 11.74 dlogZ: 787140.618 logZ: -800385.302 +/- 0.077 logLmax: -13240.54
# 09-23 15:25 nessai INFO    : it:  9196: n eval: 139098 H: 12.20 dlogZ: 593629.954 logZ: -606875.092 +/- 0.078 logLmax: -13240.54
# 09-23 15:26 nessai INFO    : it:  9981: n eval: 179098 H: 12.59 dlogZ: 477380.270 logZ: -486643.341 +/- 0.079 logLmax: -9258.08
# 09-23 15:26 nessai INFO    : it: 10000: Rolling KS test: D=0.0195, p-value=0.2157
# 09-23 15:27 nessai INFO    : it: 10570: n eval: 219098 H: 12.89 dlogZ: 401845.981 logZ: -411109.347 +/- 0.080 logLmax: -9258.08
# 09-23 15:28 nessai INFO    : it: 11035: n eval: 259098 H: 13.12 dlogZ: 358791.079 logZ: -364457.636 +/- 0.081 logLmax: -5661.04
# 09-23 15:29 nessai INFO    : it: 11409: n eval: 299098 H: 13.31 dlogZ: 322326.416 logZ: -327993.161 +/- 0.082 logLmax: -5661.04
# 09-23 15:30 nessai INFO    : Checkpointing nested sampling
# 09-23 15:31 nessai INFO    : it: 11816: n eval: 339098 H: 13.51 dlogZ: 286715.675 logZ: -292382.623 +/- 0.082 logLmax: -5661.04
# 09-23 15:31 nessai INFO    : it: 12000: Rolling KS test: D=0.017, p-value=0.3112
# 09-23 15:32 nessai INFO    : it: 12171: n eval: 379098 H: 13.69 dlogZ: 259913.461 logZ: -265580.586 +/- 0.083 logLmax: -5661.04
# 09-23 15:33 nessai INFO    : it: 12482: n eval: 419098 H: 13.84 dlogZ: 238517.502 logZ: -244184.783 +/- 0.083 logLmax: -5661.04
# 09-23 15:34 nessai INFO    : it: 12745: n eval: 459098 H: 13.97 dlogZ: 220451.128 logZ: -226118.540 +/- 0.084 logLmax: -5661.04
# 09-23 15:35 nessai INFO    : it: 13006: n eval: 499098 H: 14.10 dlogZ: 206115.376 logZ: -211782.919 +/- 0.084 logLmax: -5661.04
# 09-23 15:37 nessai INFO    : it: 13210: n eval: 539098 H: 13.55 dlogZ: 193887.182 logZ: -199554.827 +/- 0.082 logLmax: -5661.04
# 09-26 02:59 nessai INFO    : it: 78204: n eval: 93729068 H: 38.01 dlogZ: 7.326 logZ: -48.095 +/- 0.138 logLmax: -1.67
# 09-26 03:02 nessai INFO    : it: 78205: n eval: 93789068 H: 38.01 dlogZ: 7.325 logZ: -48.094 +/- 0.138 logLmax: -1.67
# 09-26 03:04 nessai INFO    : Checkpointing nested sampling
# 09-26 03:04 nessai INFO    : it: 78207: n eval: 93849068 H: 38.02 dlogZ: 7.323 logZ: -48.093 +/- 0.138 logLmax: -1.67
# 09-26 03:19 nessai INFO    : Checkpointing nested sampling
# 09-26 03:19 nessai INFO    : it: 78208: n eval: 94209068 H: 38.02 dlogZ: 7.321 logZ: -48.092 +/- 0.138 logLmax: -1.67
# 09-26 03:25 nessai INFO    : it: 78209: n eval: 94349068 H: 38.02 dlogZ: 7.320 logZ: -48.092 +/- 0.138 logLmax: -1.67
# 09-26 03:26 nessai INFO    : it: 78210: n eval: 94379068 H: 38.02 dlogZ: 7.319 logZ: -48.091 +/- 0.138 logLmax: -1.67
# 09-26 03:28 nessai INFO    : it: 78211: n eval: 94429068 H: 38.02 dlogZ: 7.318 logZ: -48.090 +/- 0.138 logLmax: -1.67
# 09-26 03:35 nessai INFO    : Checkpointing nested sampling
# 09-26 03:35 nessai INFO    : it: 78212: n eval: 94609068 H: 38.02 dlogZ: 7.317 logZ: -48.089 +/- 0.138 logLmax: -1.67
# 09-26 03:44 nessai INFO    : it: 78214: n eval: 94809068 H: 38.02 dlogZ: 7.314 logZ: -48.088 +/- 0.138 logLmax: -1.67
# 09-26 03:50 nessai INFO    : Checkpointing nested sampling
# 09-26 03:50 nessai INFO    : it: 78215: n eval: 94969068 H: 38.02 dlogZ: 7.313 logZ: -48.087 +/- 0.138 logLmax: -1.67
# 09-26 03:53 nessai INFO    : it: 78216: n eval: 95039068 H: 38.02 dlogZ: 7.312 logZ: -48.087 +/- 0.138 logLmax: -1.67
# 09-26 03:58 nessai INFO    : it: 78218: n eval: 95159068 H: 38.02 dlogZ: 7.309 logZ: -48.085 +/- 0.138 logLmax: -1.67
# 09-26 04:06 nessai INFO    : Checkpointing nested sampling
# 09-26 04:06 nessai INFO    : it: 78220: n eval: 95329068 H: 38.02 dlogZ: 7.307 logZ: -48.084 +/- 0.138 logLmax: -1.67
# 09-26 04:12 nessai INFO    : it: 78221: n eval: 95479068 H: 38.02 dlogZ: 7.306 logZ: -48.083 +/- 0.138 logLmax: -1.67
# 09-26 04:44 nessai INFO    : Checkpointing nested sampling
# 09-26 04:44 nessai INFO    : it: 78222: n eval: 96249068 H: 38.02 dlogZ: 7.305 logZ: -48.082 +/- 0.138 logLmax: -1.67
# 09-26 04:46 nessai INFO    : it: 78223: n eval: 96299068 H: 38.02 dlogZ: 7.303 logZ: -48.082 +/- 0.138 logLmax: -1.67
# 09-26 04:55 nessai INFO    : Checkpointing nested sampling
# 09-26 04:55 nessai INFO    : it: 78224: n eval: 96519068 H: 38.02 dlogZ: 7.302 logZ: -48.081 +/- 0.138 logLmax: -1.67
# 09-26 05:08 nessai INFO    : Checkpointing nested sampling
# 09-26 05:08 nessai INFO    : it: 78225: n eval: 96819068 H: 38.02 dlogZ: 7.301 logZ: -48.080 +/- 0.138 logLmax: -1.67
# 09-26 05:34 nessai INFO    : Checkpointing nested sampling
# 09-26 05:34 nessai INFO    : it: 78226: n eval: 97439068 H: 38.02 dlogZ: 7.300 logZ: -48.080 +/- 0.138 logLmax: -1.67
# 09-26 05:38 nessai INFO    : it: 78227: n eval: 97529068 H: 38.02 dlogZ: 7.299 logZ: -48.079 +/- 0.138 logLmax: -1.67
# 09-26 05:41 nessai INFO    : it: 78228: n eval: 97599068 H: 38.02 dlogZ: 7.297 logZ: -48.078 +/- 0.138 logLmax: -1.67
# 09-26 06:03 nessai INFO    : Checkpointing nested sampling
# 09-26 06:03 nessai INFO    : it: 78229: n eval: 98139068 H: 38.02 dlogZ: 7.296 logZ: -48.078 +/- 0.138 logLmax: -1.67
# 09-26 06:34 nessai INFO    : Checkpointing nested sampling
# 09-26 06:34 nessai INFO    : it: 78230: n eval: 98889068 H: 38.02 dlogZ: 7.295 logZ: -48.077 +/- 0.138 logLmax: -1.67
# 09-26 06:36 nessai INFO    : it: 78231: n eval: 98919068 H: 38.02 dlogZ: 7.294 logZ: -48.076 +/- 0.138 logLmax: -1.67
# 09-26 06:42 nessai INFO    : it: 78234: n eval: 99079068 H: 38.02 dlogZ: 7.290 logZ: -48.074 +/- 0.138 logLmax: -1.67
# 09-26 06:47 nessai INFO    : Checkpointing nested sampling
# 09-26 06:47 nessai INFO    : it: 78235: n eval: 99179068 H: 38.02 dlogZ: 7.289 logZ: -48.073 +/- 0.138 logLmax: -1.67
# 09-26 06:56 nessai INFO    : it: 78236: n eval: 99419068 H: 38.02 dlogZ: 7.288 logZ: -48.073 +/- 0.138 logLmax: -1.67
# 09-26 06:57 nessai INFO    : Checkpointing nested sampling
# 09-26 07:21 nessai INFO    : Checkpointing nested sampling
# 09-26 07:21 nessai INFO    : it: 78238: n eval: 99999068 H: 38.02 dlogZ: 7.285 logZ: -48.071 +/- 0.138 logLmax: -1.67
# 09-26 07:30 nessai INFO    : it: 78239: n eval: 100229068 H: 38.02 dlogZ: 7.284 logZ: -48.071 +/- 0.138 logLmax: -1.67
# 09-26 07:46 nessai INFO    : Checkpointing nested sampling
# 09-26 07:47 nessai INFO    : it: 78240: n eval: 100619068 H: 38.03 dlogZ: 7.283 logZ: -48.070 +/- 0.138 logLmax: -1.67
# 09-26 07:51 nessai INFO    : it: 78241: n eval: 100719068 H: 38.03 dlogZ: 7.282 logZ: -48.069 +/- 0.138 logLmax: -1.67
# 09-26 07:52 nessai INFO    : it: 78242: n eval: 100749068 H: 38.03 dlogZ: 7.281 logZ: -48.068 +/- 0.138 logLmax: -1.67
# 09-26 08:08 nessai INFO    : Checkpointing nested sampling
# 09-26 08:08 nessai INFO    : it: 78243: n eval: 101139068 H: 38.03 dlogZ: 7.279 logZ: -48.068 +/- 0.138 logLmax: -1.67
# 09-26 08:16 nessai INFO    : it: 78244: n eval: 101319068 H: 38.03 dlogZ: 7.278 logZ: -48.067 +/- 0.138 logLmax: -1.67
# 09-26 08:20 nessai INFO    : Checkpointing nested sampling
# 09-26 08:20 nessai INFO    : it: 78245: n eval: 101419068 H: 38.03 dlogZ: 7.277 logZ: -48.066 +/- 0.138 logLmax: -1.67
# 09-26 08:28 nessai INFO    : it: 78246: n eval: 101599068 H: 38.03 dlogZ: 7.276 logZ: -48.066 +/- 0.138 logLmax: -1.67
# 09-26 08:39 nessai INFO    : Checkpointing nested sampling
# 09-26 08:39 nessai INFO    : it: 78247: n eval: 101859068 H: 38.03 dlogZ: 7.275 logZ: -48.065 +/- 0.138 logLmax: -1.67
# 09-26 08:46 nessai INFO    : it: 78248: n eval: 102029068 H: 38.03 dlogZ: 7.273 logZ: -48.064 +/- 0.138 logLmax: -1.67
# 09-26 08:50 nessai INFO    : Checkpointing nested sampling
# 09-26 08:50 nessai INFO    : it: 78249: n eval: 102129068 H: 38.03 dlogZ: 7.272 logZ: -48.064 +/- 0.138 logLmax: -1.67
# 09-26 08:54 nessai INFO    : it: 78250: n eval: 102219068 H: 38.03 dlogZ: 7.271 logZ: -48.063 +/- 0.138 logLmax: -1.67
# 09-26 09:12 nessai INFO    : Checkpointing nested sampling
# 09-26 09:12 nessai INFO    : it: 78251: n eval: 102659068 H: 38.03 dlogZ: 7.270 logZ: -48.062 +/- 0.138 logLmax: -1.67
# 09-26 09:25 nessai INFO    : Checkpointing nested sampling
# 09-26 09:25 nessai INFO    : it: 78252: n eval: 102949068 H: 38.03 dlogZ: 7.269 logZ: -48.061 +/- 0.138 logLmax: -1.67
# 09-26 09:31 nessai INFO    : it: 78253: n eval: 103109068 H: 38.03 dlogZ: 7.267 logZ: -48.061 +/- 0.138 logLmax: -1.67
# 09-26 09:44 nessai INFO    : Checkpointing nested sampling
# 09-26 09:44 nessai INFO    : it: 78254: n eval: 103409068 H: 38.03 dlogZ: 7.266 logZ: -48.060 +/- 0.138 logLmax: -1.67
# 09-26 09:46 nessai INFO    : it: 78255: n eval: 103459068 H: 38.03 dlogZ: 7.265 logZ: -48.059 +/- 0.138 logLmax: -1.67
# 09-26 09:55 nessai INFO    : Checkpointing nested sampling
# 09-26 09:55 nessai INFO    : it: 78256: n eval: 103659068 H: 38.03 dlogZ: 7.264 logZ: -48.059 +/- 0.138 logLmax: -1.67
# 09-26 10:12 nessai INFO    : Checkpointing nested sampling
# 09-26 10:12 nessai INFO    : it: 78257: n eval: 104059068 H: 38.03 dlogZ: 7.263 logZ: -48.058 +/- 0.138 logLmax: -1.67
# 09-26 10:28 nessai INFO    : Checkpointing nested sampling
# 09-26 10:28 nessai INFO    : it: 78258: n eval: 104429068 H: 38.03 dlogZ: 7.261 logZ: -48.057 +/- 0.138 logLmax: -1.67
# 09-26 10:36 nessai INFO    : it: 78259: n eval: 104619068 H: 38.03 dlogZ: 7.260 logZ: -48.057 +/- 0.138 logLmax: -1.67
# 09-26 10:46 nessai INFO    : Checkpointing nested sampling
# 09-26 10:46 nessai INFO    : it: 78260: n eval: 104859068 H: 38.03 dlogZ: 7.259 logZ: -48.056 +/- 0.138 logLmax: -1.67
# 09-26 11:13 nessai INFO    : Checkpointing nested sampling
# 09-26 11:13 nessai INFO    : it: 78261: n eval: 105479068 H: 38.03 dlogZ: 7.258 logZ: -48.055 +/- 0.138 logLmax: -1.67
# 09-26 11:17 nessai INFO    : it: 78265: n eval: 105569068 H: 38.03 dlogZ: 7.253 logZ: -48.052 +/- 0.138 logLmax: -1.67
# 09-26 11:18 nessai INFO    : it: 78266: n eval: 105599068 H: 38.03 dlogZ: 7.252 logZ: -48.052 +/- 0.138 logLmax: -1.67
# 09-26 11:30 nessai INFO    : Checkpointing nested sampling
# 09-26 11:30 nessai INFO    : it: 78267: n eval: 105869068 H: 38.03 dlogZ: 7.251 logZ: -48.051 +/- 0.138 logLmax: -1.67
# 09-26 11:47 nessai INFO    : Checkpointing nested sampling
# 09-26 11:47 nessai INFO    : it: 78268: n eval: 106259068 H: 38.03 dlogZ: 7.249 logZ: -48.050 +/- 0.138 logLmax: -1.67
# 09-26 12:33 nessai INFO    : Checkpointing nested sampling
# 09-26 12:33 nessai INFO    : it: 78270: n eval: 107339068 H: 38.03 dlogZ: 7.247 logZ: -48.049 +/- 0.138 logLmax: -1.67
# 09-26 12:41 nessai INFO    : it: 78271: n eval: 107509068 H: 38.03 dlogZ: 7.246 logZ: -48.048 +/- 0.138 logLmax: -1.67
# 09-26 12:45 nessai INFO    : Checkpointing nested sampling
# 09-26 12:45 nessai INFO    : it: 78272: n eval: 107599068 H: 38.03 dlogZ: 7.245 logZ: -48.048 +/- 0.138 logLmax: -1.67
# 09-26 12:47 nessai INFO    : it: 78273: n eval: 107659068 H: 38.03 dlogZ: 7.244 logZ: -48.047 +/- 0.138 logLmax: -1.67
# 09-26 13:18 nessai INFO    : Checkpointing nested sampling
# 09-26 13:18 nessai INFO    : it: 78274: n eval: 108359068 H: 38.04 dlogZ: 7.242 logZ: -48.046 +/- 0.138 logLmax: -1.67
# 09-26 13:23 nessai INFO    : it: 78275: n eval: 108469068 H: 38.04 dlogZ: 7.241 logZ: -48.045 +/- 0.138 logLmax: -1.67
# 09-26 13:26 nessai INFO    : it: 78276: n eval: 108539068 H: 38.04 dlogZ: 7.240 logZ: -48.045 +/- 0.138 logLmax: -1.67
# 09-26 13:28 nessai INFO    : Checkpointing nested sampling
# 09-26 13:28 nessai INFO    : it: 78277: n eval: 108599068 H: 38.04 dlogZ: 7.239 logZ: -48.044 +/- 0.138 logLmax: -1.67
# 09-26 13:29 nessai WARNING : Terminating run
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 09-26 13:29 nessai INFO    : Starting to close worker pool.
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 13:29 bilby WARNING : Sampler is not initialized
# 13:29 bilby INFO    : Run interrupted by signal 15: checkpoint and exit on 130
# 09-26 13:29 nessai INFO    : Finished closing worker pool.
# 09-26 13:29 nessai INFO    : Checkpointing nested sampling
# 13:29 bilby INFO    : Run interrupted by signal 2: checkpoint and exit on 130
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 130
# /home/ps/miniconda3/envs/tdc/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3558: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)

# %%
result.plot_corner(save=True)
