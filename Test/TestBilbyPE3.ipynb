# %%
# limit the thread used by numpy 
import os
os.environ["OMP_NUM_THREADS"] = "1"
os.environ["OPENBLAS_NUM_THREADS"] = "1"
os.environ["MKL_NUM_THREADS"] = "1"
os.environ["NUMEXPR_NUM_THREADS"] = "1"
os.environ["VECLIB_MAXIMUM_THREADS"] = "1"  

import numpy as np
import scipy.interpolate as interp 
try:
    import cupy as xp
    import cupyx.scipy.interpolate as xinterp
    # print("has cupy")
except (ImportError, ModuleNotFoundError) as e:
    import numpy as xp
    import scipy.interpolate as xinterp  
    # print("no cupy")

from tqdm import tqdm
import pickle
import matplotlib.pyplot as plt
# import matplotlib
# matplotlib.rcParams['text.usetex'] = True
# matplotlib.rcParams['font.family'] = 'serif'

from Triangle.Constants import *
from Triangle.Orbit import * 
from Triangle.Noise import *
from Triangle.FFTTools import *
from Triangle.TDI import *
from Triangle.Data import * 

from Triangle_BBH.Waveform import * 
from Triangle_BBH.Response import *
from Triangle_BBH.Utils import *
from Triangle_BBH.Fisher import *

# import multiprocessing

np.random.seed(114516)
xp.random.seed(114516)

# %% [markdown]
# ## Data settings

# %%
t_start = 10. * DAY # start time in s
Tobs = 5. * DAY # data length in s 
t_end = t_start + Tobs # end time in s 
dt = 10. # time cadance in s 
fsample = 1. / dt # sampling rate in Hz 
data_frequencies = np.fft.rfftfreq(n=int(Tobs/dt), d=dt) # frequecies where waveform will be calculated 
delta_f = 1. / Tobs

data_frequencies.shape
# Out:
# (21601,)

# %%
# mask the "null" frequencies, which may cause singularity in the calculation of likelihood 
mask = np.ones_like(data_frequencies, dtype=bool)
for i in range(1, 40): 
    mask_idx = np.where(np.abs(data_frequencies - i*0.025)<i*3e-4)[0]
    mask[mask_idx] = False 
data_frequencies = data_frequencies[mask]

# remove the frequencies below Taiji sensitive band 
mask = np.where(data_frequencies > 1e-5)[0]
data_frequencies = data_frequencies[mask]
data_frequencies_GPU = xp.array(data_frequencies)

data_frequencies.shape
# Out:
# (21077,)

# %% [markdown]
# ## Set response model

# %%
# the path of Taiji orbit 
orbit_GPU = Orbit(OrbitDir="../../Triangle-Simulator/OrbitData/MicroSateOrbitEclipticTCB") # create individial orbit objects for CPU and GPU to avoid the confusion of numpy / cupy orbit data 

# initialize  waveform generator 
WFG_GPU = BBHxWaveformGenerator(mode="primary", use_gpu=True)

# initialize response generator 
FDTDI_GPU = BBHxFDTDIResponseGenerator(orbit_class=orbit_GPU, waveform_generator=WFG_GPU, use_gpu=True)

# response settings 
response_kwargs_GPU = dict(
    modes=[(2,2)], 
    tmin=t_start / DAY, # start time in day 
    tmax=t_end / DAY, # end time in day  
    TDIGeneration="2nd", # "1st" or "2nd"
    optimal_combination=True, # True for AET, False for XYZ 
    output_by_mode=False, 
    interpolation=True,
)

# %% [markdown]
# ## Waveform generation

# %%
mbhb_parameters = {
    'chirp_mass': np.power(10., np.random.uniform(5.5, 6.5)), # [Solar mass], for chirp_mass of 10^5 or smaller, a smaller dt is needed
    'mass_ratio': np.random.uniform(0.1, 1.), 
    'spin_1z': np.random.uniform(-0.99, 0.99),
    'spin_2z': np.random.uniform(-0.99, 0.99),
    'coalescence_time': np.random.uniform(t_start + DAY, t_end) / DAY, # [day], start from t_start to ensure that at least 1-day waveform is within the data
    'coalescence_phase': np.random.uniform(0, TWOPI),
    'luminosity_distance': np.power(10., np.random.uniform(4., 5.)), # [MPC]
    'inclination': np.arccos(np.random.uniform(-1., 1.)), # [rad]
    'longitude': np.random.uniform(0, TWOPI), # [rad]
    'latitude': np.arcsin(np.random.uniform(-1., 1.)), # [rad]
    'psi': np.random.uniform(0, PI) # [rad]
    }
mbhb_parameters
# Out:
# {'chirp_mass': 2617841.5700112376,
#  'mass_ratio': 0.34404218182157137,
#  'spin_1z': -0.9598891166162299,
#  'spin_2z': 0.9495486198496021,
#  'coalescence_time': 11.113040458258068,
#  'coalescence_phase': 4.03185217221938,
#  'luminosity_distance': 20415.100096656082,
#  'inclination': 1.5614316033683615,
#  'longitude': 6.227128600461051,
#  'latitude': 0.11609670776293429,
#  'psi': 0.5147056761692285}

# %%
wf_channels = FDTDI_GPU.Response(mbhb_parameters, data_frequencies_GPU, **response_kwargs_GPU)
wf_channels.shape
# Out:
# (3, 21077)

# %% [markdown]
# ## Noise generation

# %%
arm_time = (t_start + t_end) / 2. 
arms = dict()
for key in MOSA_labels:
    arms[key] = orbit_GPU.LTTfunctions()[key](arm_time)
# print("arm lengths:", arms)

# theoretical PSDs at the given armlengths 
PSDfunc = TDIPSDs()
PSD_channels = np.array([
    PSDfunc.PSD_A2_unequal(data_frequencies, arms), 
    PSDfunc.PSD_E2_unequal(data_frequencies, arms), 
    PSDfunc.PSD_T2_unequal(data_frequencies, arms)
])

# generate frequency-domain noises as Gaussian and stationary 
Re_tmp = np.random.normal(scale=np.sqrt(PSD_channels / 4. / delta_f))
Im_tmp = np.random.normal(scale=np.sqrt(PSD_channels / 4. / delta_f))
noise_channels = xp.array(Re_tmp + 1.j * Im_tmp) 

# covariance matrix 
CovMat = np.array([
    [PSD_channels[0], np.zeros_like(PSD_channels[0]), np.zeros_like(PSD_channels[0])],
    [np.zeros_like(PSD_channels[0]), PSD_channels[1], np.zeros_like(PSD_channels[0])],
    [np.zeros_like(PSD_channels[0]), np.zeros_like(PSD_channels[0]), PSD_channels[2]]
]) / 4. / delta_f # (3, 3, Nf)

# inverse of covmatrix
InvCovMat = np.linalg.inv(np.transpose(CovMat, (2, 0, 1))) # (Nf, 3, 3)
InvCovMat[:, 2, 2] *= 0. # use A, E channels only in the following analysis 

PSD_channels.shape, noise_channels.shape, InvCovMat.shape
# Out:
# ((3, 21077), (3, 21077), (21077, 3, 3))

# %% [markdown]
# ## Data combination

# %%
data_channels = wf_channels + noise_channels

# %%
for ichannel, nchannel in enumerate(["A", "E", "T"]): 
    plt.loglog(data_frequencies, np.abs(data_channels[ichannel].get()), linewidth=1, alpha=0.5, color=BLUE)
    plt.loglog(data_frequencies, np.abs(wf_channels[ichannel].get()), color=RED, linestyle=":")
    plt.loglog(data_frequencies, np.sqrt(PSD_channels[ichannel] * Tobs / 2.), color="grey", linestyle="--")
plt.xlabel("Frequency (Hz)")
plt.ylabel("Frequency-domain data (1/Hz)")
# Out:
# Text(0, 0.5, 'Frequency-domain data (1/Hz)')

# %% [markdown]
# ## Fisher analysis
# calculate the theoretical bounds

# %%
def fisher_waveform_wrapper(param_dict, frequencies):
    res = FDTDI_GPU.Response(
        parameters=param_dict, 
        freqs=xp.array(frequencies),  
        **response_kwargs_GPU, 
    )
    return res.get()

# set initial steps 
analyze_param_step_dict = {
    'chirp_mass': 10.,
    'mass_ratio': 0.01,
    'spin_1z': 0.01,
    'spin_2z': 0.01,
    'coalescence_time': 0.001,
    'coalescence_phase': 0.001,
    'luminosity_distance': 10.,
    'inclination': 0.01,
    'longitude': 0.01,
    'latitude': 0.01,
    'psi': 0.01
    }
for k, v in analyze_param_step_dict.items():
    analyze_param_step_dict[k] = -v 

FIM = MultiChannelFisher(
    waveform_generator=fisher_waveform_wrapper, 
    param_dict=mbhb_parameters, 
    analyze_param_step_dict=analyze_param_step_dict, 
    frequency=data_frequencies, 
    inverse_covariance=InvCovMat, 
    verbose=1,
)

FIM.auto_test_step()
FIM.calculate_Fisher()
FIM.calculate_errors()
# Out:
# 11 parameters in total: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# 11 analyzed parameters: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# parameters whose steps should be tested: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
#
#  ========= testing parameter chirp_mass ==========
# error = 27.82224209110509
# shift = 5.0 relative diff = 4.793598388690943e-07
# shift of parameter chirp_mass is 5.0
#
#  ========= testing parameter mass_ratio ==========
# error = 0.013167640123622492
# shift = 0.005 relative diff = 0.000413903398984416
# error = 0.013165397215359064
# shift = 0.0025 relative diff = 0.0004360361526440892
# error = 0.01316645216268253
# shift = 0.00125 relative diff = 6.958594639925846e-05
# shift of parameter mass_ratio is 0.00125
#
#  ========= testing parameter spin_1z ==========
# error = 0.03386054895077608
# shift = 0.005 relative diff = 0.0006273168549407618
# error = 0.03387987957822839
# shift = 0.0025 relative diff = 0.0007620575674743756
# error = 0.03388912768703564
# shift = 0.00125 relative diff = 0.0003513454269109777
# error = 0.033893647295965855
# shift = 0.000625 relative diff = 0.0001690606131401669
# error = 0.03389588180849347
# shift = 0.0003125 relative diff = 8.288527424022103e-05
# shift of parameter spin_1z is 0.0003125
#
#  ========= testing parameter spin_2z ==========
# error = 0.07704139560307009
# shift = 0.005 relative diff = 0.00013775213575802057
# error = 0.0770521928227276
# shift = 0.0025 relative diff = 0.00017263835192095768
# error = 0.07705763927824473
# shift = 0.00125 relative diff = 8.760085814899872e-05
# shift of parameter spin_2z is 0.00125
#
#  ========= testing parameter coalescence_time ==========
# error = 0.0011724501033239384
# shift = 0.0005 relative diff = 0.007690612073627084
# error = 0.0011679979567158021
# shift = 0.00025 relative diff = 0.008323620884480479
# error = 0.0011668884549518393
# shift = 0.000125 relative diff = 0.00205961710077626
# error = 0.0011666113278459326
# shift = 6.25e-05 relative diff = 0.0005135581926502478
# error = 0.0011665420756013986
# shift = 3.125e-05 relative diff = 0.00012829081142307934
# error = 0.0011665247713863896
# shift = 1.5625e-05 relative diff = 3.2059119283920875e-05
# shift of parameter coalescence_time is 1.5625e-05
#
#  ========= testing parameter coalescence_phase ==========
# error = 0.024700748260131866
# shift = 0.0005 relative diff = 3.1279289065969065e-08
# shift of parameter coalescence_phase is 0.0005
#
#  ========= testing parameter luminosity_distance ==========
# error = 4.991763891534815
# shift = 5.0 relative diff = 6.121044885057187e-05
# shift of parameter luminosity_distance is 5.0
#
#  ========= testing parameter inclination ==========
# error = 0.05009093558927436
# shift = 0.005 relative diff = 0.00010813225681894923
# error = 0.05008461023789732
# shift = 0.0025 relative diff = 0.00014145935151679004
# error = 0.05008122094829058
# shift = 0.00125 relative diff = 8.038762828552003e-05
# shift of parameter inclination is 0.00125
#
#  ========= testing parameter longitude ==========
# error = 0.01527395064301893
# shift = 0.005 relative diff = 0.0001232518070898008
# error = 0.015272262497995083
# shift = 0.0025 relative diff = 0.00014925483152413842
# error = 0.015271467007302293
# shift = 0.00125 relative diff = 6.780880130331663e-05
# shift of parameter longitude is 0.00125
#
#  ========= testing parameter latitude ==========
# error = 0.0267492701470916
# shift = 0.005 relative diff = 6.80237968671908e-05
# shift of parameter latitude is 0.005
#
#  ========= testing parameter psi ==========
# error = 0.04999728381807377
# shift = 0.005 relative diff = 0.0001214421256059099
# error = 0.04999973840193053
# shift = 0.0025 relative diff = 0.000127645392260605
# error = 0.050000060249836546
# shift = 0.00125 relative diff = 2.479884224041024e-05
# shift of parameter psi is 0.00125
# all parameters tested.
# errors:
# {'chirp_mass': 5951.109949591015, 'mass_ratio': 0.0035964235402287732, 'spin_1z': 0.04588021254306234, 'spin_2z': 0.1333491597995496, 'coalescence_time': 0.0005923472985284655, 'coalescence_phase': 0.01656449408523355, 'luminosity_distance': 722.7304257912548, 'inclination': 0.004601663677759221, 'longitude': 0.10249311382676854, 'latitude': 0.2300405322281625, 'psi': 0.8425279347184539}

# %%
FIM.param_errors
# Out:
# {'chirp_mass': 5951.109949591015,
#  'mass_ratio': 0.0035964235402287732,
#  'spin_1z': 0.04588021254306234,
#  'spin_2z': 0.1333491597995496,
#  'coalescence_time': 0.0005923472985284655,
#  'coalescence_phase': 0.01656449408523355,
#  'luminosity_distance': 722.7304257912548,
#  'inclination': 0.004601663677759221,
#  'longitude': 0.10249311382676854,
#  'latitude': 0.2300405322281625,
#  'psi': 0.8425279347184539}

# %%
opt_SNR = FrequencyDomainCovarianceSNR(wf_channels.get(), InvCovMat)
opt_SNR
# Out:
# 819.5015818467616

# %% [markdown]
# ## Likelihood

# %%
Like = Likelihood(
    response_generator=FDTDI_GPU, 
    frequency=data_frequencies_GPU, 
    data=data_channels,
    invserse_covariance_matrix=InvCovMat, 
    response_parameters=response_kwargs_GPU, 
    use_gpu=True,
)
# Out:
# number of freuqncies: 21077
# min and max frequencies: 1.1574074074074073e-05 0.04939814814814815
# response kwargs: {'modes': [(2, 2)], 'tmin': 10.0, 'tmax': 15.0, 'TDIGeneration': '2nd', 'optimal_combination': True, 'output_by_mode': False, 'interpolation': True}

# %%
fiducial_param_arr = ParamDict2ParamArr(mbhb_parameters)

N_test=101
test_idx = 0 # lgMc 
test_params = np.linspace(-1e-3, 1e-3, N_test) + fiducial_param_arr[test_idx]

full_lls = [] # store the full loglikelihood 
for i_test in range(N_test):
    tmp_params = np.array(fiducial_param_arr).copy()
    tmp_params[test_idx] = test_params[i_test]
    full_lls.append(Like.full_log_like(tmp_params))
full_lls = np.array(full_lls)

plt.plot((test_params - fiducial_param_arr[test_idx])*1e3, full_lls - np.max(full_lls), label="full logLike")
plt.xlabel(r'$\Delta {\rm lg} \mathcal{M}c \ (10^{-3})$')
plt.ylabel(r'$\Delta {\rm ln} \mathcal{L}$')
plt.legend(frameon=False)

# %% [markdown]
# ## Bilby wrapper

# %%
import bilby

# %%
priors = bilby.core.prior.PriorDict()
priors["chirp_mass"] = bilby.prior.Uniform(minimum=mbhb_parameters["chirp_mass"]-10.*FIM.param_errors["chirp_mass"], maximum=mbhb_parameters["chirp_mass"]+10.*FIM.param_errors["chirp_mass"], name='chirp_mass', latex_label='$\mathcal{M}_c$')
priors["mass_ratio"] = bilby.prior.Uniform(minimum=max(0.1, mbhb_parameters["mass_ratio"]-10.*FIM.param_errors["mass_ratio"]), maximum=min(1., mbhb_parameters["mass_ratio"]+10.*FIM.param_errors["mass_ratio"]), name="mass_ratio", latex_label='$q$')
priors["spin_1z"] = bilby.prior.Uniform(minimum=max(-0.99, mbhb_parameters["spin_1z"]-10.*FIM.param_errors["spin_1z"]), maximum=min(0.99, mbhb_parameters["spin_1z"]+10.*FIM.param_errors["spin_1z"]), name="spin_1z", latex_label='$\chi_{z1}$')
priors["spin_2z"] = bilby.prior.Uniform(minimum=max(-0.99, mbhb_parameters["spin_2z"]-10.*FIM.param_errors["spin_2z"]), maximum=min(0.99, mbhb_parameters["spin_2z"]+10.*FIM.param_errors["spin_2z"]), name="spin_2z", latex_label='$\chi_{z2}$')
priors["coalescence_time"] = bilby.prior.Uniform(minimum=mbhb_parameters["coalescence_time"]-10.*FIM.param_errors["coalescence_time"], maximum=mbhb_parameters["coalescence_time"]+10.*FIM.param_errors["coalescence_time"], name="coalescence_time", latex_label='$t_c$') 
priors["coalescence_phase"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="coalescence_phase", latex_label='$\\varphi_c$', boundary="periodic")
priors["luminosity_distance"] = bilby.prior.Uniform(minimum=mbhb_parameters["luminosity_distance"]-10.*FIM.param_errors["luminosity_distance"], maximum=mbhb_parameters["luminosity_distance"]+10.*FIM.param_errors["luminosity_distance"], name="luminosity_distance", latex_label='$d_L$')
priors["inclination"] = bilby.prior.Sine(minimum=0., maximum=PI, name="inclination", latex_label='$\iota$')
priors["longitude"] = bilby.prior.Uniform(minimum=0., maximum=TWOPI, name="longitude", latex_label='$\lambda$', boundary="periodic")
priors["latitude"] = bilby.prior.Cosine(minimum=-PI/2., maximum=PI/2., name="latitude", latex_label='$\\beta$')
priors["psi"] = bilby.prior.Uniform(minimum=0., maximum=PI, name="psi", latex_label='$\psi$', boundary="periodic")

# %%
priors
# Out:
# {'chirp_mass': Uniform(minimum=2558330.4705153275, maximum=2677352.6695071477, name='chirp_mass', latex_label='$\\mathcal{M}_c$', unit=None, boundary=None),
#  'mass_ratio': Uniform(minimum=0.30807794641928365, maximum=0.3800064172238591, name='mass_ratio', latex_label='$q$', unit=None, boundary=None),
#  'spin_1z': Uniform(minimum=-0.99, maximum=-0.5010869911856064, name='spin_1z', latex_label='$\\chi_{z1}$', unit=None, boundary=None),
#  'spin_2z': Uniform(minimum=-0.3839429781458936, maximum=0.99, name='spin_2z', latex_label='$\\chi_{z2}$', unit=None, boundary=None),
#  'coalescence_time': Uniform(minimum=11.107116985272784, maximum=11.118963931243352, name='coalescence_time', latex_label='$t_c$', unit=None, boundary=None),
#  'coalescence_phase': Uniform(minimum=0.0, maximum=6.283185307179586, name='coalescence_phase', latex_label='$\\varphi_c$', unit=None, boundary='periodic'),
#  'luminosity_distance': Uniform(minimum=13187.795838743536, maximum=27642.40435456863, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None),
#  'inclination': Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None),
#  'longitude': Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic'),
#  'latitude': Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None),
#  'psi': Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')}

# %%
class bilby_likelihood_wrapper(bilby.Likelihood):
    def __init__(self, triangle_likelihood, likelihood_type="full"):
        """ wrap a triangle likelihood to get a bilby likelihood, type can be "full" or "heterodyned" """
        super().__init__(
            parameters={
                'chirp_mass': None,
                'mass_ratio': None,
                'spin_1z': None,
                'spin_2z': None,
                'coalescence_time': None,
                'coalescence_phase': None,
                'luminosity_distance': None,
                'inclination': None,
                'longitude': None,
                'latitude': None,
                'psi': None
            }
        )
        if likelihood_type == "full":
            self.LLfunc = triangle_likelihood.full_log_like
        elif likelihood_type == "heterodyned":
            self.LLfunc = triangle_likelihood.het_log_like
        else:
            raise ValueError("wrong likelihood type. it should only be full or heterodyned.")

    def log_likelihood(self):
        return self.LLfunc(ParamDict2ParamArr(self.parameters))

# %%
BLike_full = bilby_likelihood_wrapper(triangle_likelihood=Like, likelihood_type="full")

# %%
sampler_name = "nessai"
# sampler_name = "dynesty"

# %%
# import multiprocessing
# print("number of cpus =", multiprocessing.cpu_count())

result = bilby.run_sampler(
    likelihood=BLike_full, 
    priors=priors,
    sampler=sampler_name, 
    nlive=1000,
    walks=20,
    nact=50,
    maxmcmc=2000,
    dlogz=0.3,
    # npool=multiprocessing.cpu_count(),
    npool=None, 
    injection_parameters=mbhb_parameters, 
    outdir="../../Results/bilby_outdir",
    label="test_full_likelihood_5day3",
    plot=True,
    resume=False, 
    # resume=True, 
)
# Out:
# 19:00 bilby INFO    : Running for label 'test_full_likelihood_5day3', output will be saved to '../../Results/bilby_outdir'
# /home/ps/miniconda3/envs/tri_env/lib/python3.9/site-packages/bilby/core/utils/log.py:73: UserWarning: The '__version__' attribute is deprecated and will be removed in MarkupSafe 3.1. Use feature detection, or `importlib.metadata.version("markupsafe")`, instead.
#   vdict[key] = str(getattr(sys.modules[key], "__version__", "N/A"))
# 19:00 bilby INFO    : Analysis priors:
# 19:00 bilby INFO    : chirp_mass=Uniform(minimum=2558330.4705153275, maximum=2677352.6695071477, name='chirp_mass', latex_label='$\\mathcal{M}_c$', unit=None, boundary=None)
# 19:00 bilby INFO    : mass_ratio=Uniform(minimum=0.30807794641928365, maximum=0.3800064172238591, name='mass_ratio', latex_label='$q$', unit=None, boundary=None)
# 19:00 bilby INFO    : spin_1z=Uniform(minimum=-0.99, maximum=-0.5010869911856064, name='spin_1z', latex_label='$\\chi_{z1}$', unit=None, boundary=None)
# 19:00 bilby INFO    : spin_2z=Uniform(minimum=-0.3839429781458936, maximum=0.99, name='spin_2z', latex_label='$\\chi_{z2}$', unit=None, boundary=None)
# 19:00 bilby INFO    : coalescence_time=Uniform(minimum=11.107116985272784, maximum=11.118963931243352, name='coalescence_time', latex_label='$t_c$', unit=None, boundary=None)
# 19:00 bilby INFO    : coalescence_phase=Uniform(minimum=0.0, maximum=6.283185307179586, name='coalescence_phase', latex_label='$\\varphi_c$', unit=None, boundary='periodic')
# 19:00 bilby INFO    : luminosity_distance=Uniform(minimum=13187.795838743536, maximum=27642.40435456863, name='luminosity_distance', latex_label='$d_L$', unit=None, boundary=None)
# 19:00 bilby INFO    : inclination=Sine(minimum=0.0, maximum=3.141592653589793, name='inclination', latex_label='$\\iota$', unit=None, boundary=None)
# 19:00 bilby INFO    : longitude=Uniform(minimum=0.0, maximum=6.283185307179586, name='longitude', latex_label='$\\lambda$', unit=None, boundary='periodic')
# 19:00 bilby INFO    : latitude=Cosine(minimum=-1.5707963267948966, maximum=1.5707963267948966, name='latitude', latex_label='$\\beta$', unit=None, boundary=None)
# 19:00 bilby INFO    : psi=Uniform(minimum=0.0, maximum=3.141592653589793, name='psi', latex_label='$\\psi$', unit=None, boundary='periodic')
# 19:00 bilby INFO    : Analysis likelihood class: <class '__main__.bilby_likelihood_wrapper'>
# 19:00 bilby INFO    : Analysis likelihood noise evidence: nan
# 19:00 bilby INFO    : Single likelihood evaluation took nan s
# 19:00 bilby WARNING : Supplied argument 'walks' not an argument of 'Nessai', removing.
# 19:00 bilby WARNING : Supplied argument 'nact' not an argument of 'Nessai', removing.
# 19:00 bilby WARNING : Supplied argument 'maxmcmc' not an argument of 'Nessai', removing.
# 19:00 bilby WARNING : Supplied argument 'dlogz' not an argument of 'Nessai', removing.
# 19:00 bilby INFO    : Using sampler Nessai with kwargs {'n_steps': 10, 'n_accept': None, 'step_type': 'gaussian', 'step_kwargs': None, 'plot_chain': False, 'plot_history': False, 'enforce_likelihood_threshold': True, 'ensemble_fraction': 0.5, 'rng': None, 'flow_config': None, 'training_config': None, 'output': '../../Results/bilby_outdir/test_full_likelihood_5day3_nessai/', 'poolsize': 1000, 'plot': True, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'max_n_clusters': None, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False, 'augment_dims': 1, 'generate_augment': 'gaussian', 'marginalise_augment': False, 'n_marg': 50, 'nlive': 1000, 'stopping': 0.1, 'max_iteration': None, 'checkpointing': True, 'checkpoint_interval': 600, 'checkpoint_on_iteration': False, 'checkpoint_on_training': False, 'checkpoint_callback': None, 'logging_interval': 60, 'log_on_iteration': False, 'resume_file': 'nested_sampler_resume.pkl', 'seed': None, 'pool': None, 'close_pool': None, 'n_pool': None, 'proposal_plots': False, 'prior_sampling': False, 'analytic_priors': False, 'maximum_uninformed': None, 'uninformed_proposal': None, 'uninformed_acceptance_threshold': None, 'uninformed_proposal_kwargs': None, 'flow_proposal_class': None, 'flow_class': None, 'training_frequency': None, 'train_on_empty': True, 'cooldown': 200, 'memory': False, 'reset_weights': False, 'reset_permutations': False, 'reset_flow': False, 'retrain_acceptance': True, 'reset_acceptance': False, 'acceptance_threshold': 0.01, 'shrinkage_expectation': 'logt', 'trace_parameters': None, 'resume': False, 'resume_data': None, 'weights_file': None, 'weights_path': None, 'exit_code': 130, 'pytorch_threads': 1, 'eps': None, 'torch_dtype': None, 'disable_vectorisation': False, 'likelihood_chunksize': None, 'allow_multi_valued_likelihood': None, 'parallelise_prior': None, 'result_extension': 'hdf5', 'plot_indices': True, 'plot_posterior': False, 'plot_logXlogL': True, 'posterior_sampling_method': None, 'nessai_log_level': None, 'nessai_logging_stream': 'stdout', 'nessai_plot': True, 'nessai_likelihood_constraint': True}
# 07-14 19:00 nessai INFO    : Running Nessai version 0.14.0.post0
# 07-14 19:00 nessai INFO    : pool and n_pool are none, no multiprocessing pool
# 07-14 19:00 nessai INFO    : Initialising nested sampler
# /home/ps/miniconda3/envs/tri_env/lib/python3.9/site-packages/nessai/utils/logging.py:133: FutureWarning: setup_logger is deprecated, use configure_logger instead
#   warnings.warn(
# 07-14 19:00 nessai WARNING : Multiprocessing pool has already been configured.
# 07-14 19:00 nessai WARNING : Removing unused keyword arguments ({'max_n_clusters', 'plot_chain', 'enforce_likelihood_threshold', 'plot_history', 'n_accept', 'step_kwargs', 'marginalise_augment', 'n_steps', 'augment_dims', 'ensemble_fraction', 'n_marg', 'step_type', 'generate_augment'}) from kwargs for FlowProposal. These are valid keyword arguments but correspond to other proposal classes.
# 07-14 19:00 nessai INFO    : Passing kwargs to FlowProposal: {'training_config': None, 'poolsize': 1000, 'check_acceptance': False, 'max_poolsize_scale': 10, 'update_poolsize': True, 'accumulate_weights': False, 'save_training_data': False, 'reparameterisations': None, 'fallback_reparameterisation': 'zscore', 'use_default_reparameterisations': None, 'reverse_reparameterisations': False, 'map_to_unit_hypercube': False, 'latent_prior': 'truncated_gaussian', 'constant_volume_mode': True, 'volume_fraction': 0.95, 'fuzz': 1.0, 'fixed_radius': False, 'drawsize': None, 'truncate_log_q': False, 'expansion_fraction': 4.0, 'min_radius': False, 'max_radius': 50.0, 'compute_radius_with_all': False}
# 07-14 19:00 nessai WARNING : Signal handling is disabled. nessai will not automatically checkpoint when exited.
# 07-14 19:00 nessai INFO    : No reparameterisations provided, using default reparameterisations included in FlowProposal
# 07-14 19:00 nessai INFO    : Adding reparameterisations from: {}
# 07-14 19:00 nessai INFO    : Assuming fallback reparameterisation (ScaleAndShift) for ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi'] with kwargs: {'estimate_scale': True, 'estimate_shift': True, 'prior_bounds': {'chirp_mass': array([2558330.47051533, 2677352.66950715]), 'mass_ratio': array([0.30807795, 0.38000642]), 'spin_1z': array([-0.99      , -0.50108699]), 'spin_2z': array([-0.38394298,  0.99      ]), 'coalescence_time': array([11.10711699, 11.11896393]), 'coalescence_phase': array([0.        , 6.28318531]), 'luminosity_distance': array([13187.79583874, 27642.40435457]), 'inclination': array([0.        , 3.14159265]), 'longitude': array([0.        , 6.28318531]), 'latitude': array([-1.57079633,  1.57079633]), 'psi': array([0.        , 3.14159265])}}.
# 07-14 19:00 nessai INFO    : x space parameters: ['chirp_mass', 'mass_ratio', 'spin_1z', 'spin_2z', 'coalescence_time', 'coalescence_phase', 'luminosity_distance', 'inclination', 'longitude', 'latitude', 'psi']
# 07-14 19:00 nessai INFO    : x prime space parameters: ['chirp_mass_prime', 'mass_ratio_prime', 'spin_1z_prime', 'spin_2z_prime', 'coalescence_time_prime', 'coalescence_phase_prime', 'luminosity_distance_prime', 'inclination_prime', 'longitude_prime', 'latitude_prime', 'psi_prime']
# 07-14 19:00 nessai INFO    : Overwriting fuzz factor with expansion fraction
# 07-14 19:00 nessai INFO    : New fuzz factor: 1.1575579117706545
# 07-14 19:00 nessai INFO    : Verifying rescaling functions
# 07-14 19:00 nessai INFO    : Rescaling functions are invertible
# 07-14 19:00 nessai INFO    : Populating initial live points
# 07-14 19:01 nessai INFO    : Populated 100 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 200 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 300 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 400 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 500 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 600 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 700 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 800 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 900 / 1000 live points
# 07-14 19:01 nessai INFO    : Populated 1000 / 1000 live points
# 07-14 19:01 nessai INFO    : Starting nested sampling loop
# 07-14 19:02 nessai INFO    : it:   689: n eval: 3000 H: 7.60 dlogZ: 1511207.557 logZ: -1589050.133 +/- 0.087 logLmax: -77841.89
# 07-14 19:02 nessai INFO    : it:  1000: Rolling KS test: D=0.006, p-value=0.9268
# 07-14 19:03 nessai INFO    : it:  1589: n eval: 6000 H: 8.50 dlogZ: 732699.843 logZ: -810543.320 +/- 0.092 logLmax: -77841.89
# 07-14 19:04 nessai INFO    : it:  2000: Rolling KS test: D=0.013, p-value=0.7071
# 07-14 19:04 nessai INFO    : Switching to FlowProposal
# 07-14 19:05 nessai INFO    : it:  2001: n eval: 10355 H: 8.91 dlogZ: 576979.542 logZ: -654823.430 +/- 0.094 logLmax: -77841.89
# 07-14 19:06 nessai INFO    : it:  2314: n eval: 13469 H: 9.22 dlogZ: 504429.066 logZ: -582273.267 +/- 0.096 logLmax: -77841.89
# 07-14 19:07 nessai INFO    : it:  2661: n eval: 17155 H: 9.57 dlogZ: 422572.585 logZ: -500417.133 +/- 0.098 logLmax: -77841.89
# 07-14 19:09 nessai INFO    : it:  2981: n eval: 21558 H: 9.89 dlogZ: 372088.562 logZ: -447296.263 +/- 0.099 logLmax: -75204.72
# 07-14 19:09 nessai INFO    : it:  3000: Rolling KS test: D=0.029, p-value=0.1825
# 07-14 19:11 nessai INFO    : Checkpointing nested sampling
# 07-14 23:39 nessai INFO    : it:  7994: n eval: 687959 H: 14.90 dlogZ: 49151.062 logZ: -94590.319 +/- 0.122 logLmax: -45431.26
# 07-14 23:39 nessai INFO    : it:  8000: Rolling KS test: D=0.023, p-value=0.3419
# 07-14 23:43 nessai INFO    : it:  8022: n eval: 697959 H: 14.93 dlogZ: 48757.781 logZ: -94197.066 +/- 0.122 logLmax: -45431.26
# 07-14 23:47 nessai INFO    : it:  8052: n eval: 707959 H: 14.96 dlogZ: 48149.345 logZ: -93588.660 +/- 0.122 logLmax: -45431.26
# 07-14 23:51 nessai INFO    : Checkpointing nested sampling
# 07-14 23:51 nessai INFO    : it:  8077: n eval: 717959 H: 14.98 dlogZ: 47550.433 logZ: -92989.773 +/- 0.122 logLmax: -45431.26
# 07-14 23:55 nessai INFO    : it:  8108: n eval: 727959 H: 15.02 dlogZ: 46881.776 logZ: -92321.147 +/- 0.123 logLmax: -45431.26
# 07-14 23:59 nessai INFO    : it:  8142: n eval: 737959 H: 15.03 dlogZ: 46385.203 logZ: -91824.608 +/- 0.123 logLmax: -45431.26
# 07-15 00:03 nessai INFO    : Checkpointing nested sampling
# 07-15 00:03 nessai INFO    : it:  8171: n eval: 747959 H: 14.56 dlogZ: 45827.354 logZ: -91266.789 +/- 0.121 logLmax: -45431.26
# 07-15 00:07 nessai INFO    : it:  8196: n eval: 757959 H: 15.10 dlogZ: 45419.120 logZ: -90858.580 +/- 0.123 logLmax: -45431.26
# 07-15 00:11 nessai INFO    : it:  8224: n eval: 767959 H: 15.13 dlogZ: 44884.824 logZ: -90324.311 +/- 0.123 logLmax: -45431.26
# 07-15 00:15 nessai INFO    : Checkpointing nested sampling
# 07-15 00:15 nessai INFO    : it:  8246: n eval: 777959 H: 15.15 dlogZ: 44586.156 logZ: -90025.665 +/- 0.123 logLmax: -45431.26
# 07-15 00:20 nessai INFO    : it:  8274: n eval: 787959 H: 15.18 dlogZ: 44066.816 logZ: -89506.353 +/- 0.123 logLmax: -45431.26
# 07-15 00:24 nessai INFO    : it:  8300: n eval: 797959 H: 15.21 dlogZ: 43564.625 logZ: -89004.189 +/- 0.123 logLmax: -45431.26
# 07-15 00:28 nessai INFO    : Checkpointing nested sampling
# 07-15 00:28 nessai INFO    : it:  8326: n eval: 807959 H: 15.23 dlogZ: 43306.477 logZ: -88746.066 +/- 0.123 logLmax: -45431.26
# 07-15 00:32 nessai INFO    : it:  8348: n eval: 817959 H: 15.17 dlogZ: 42899.892 logZ: -88339.503 +/- 0.123 logLmax: -45431.26
# 07-15 00:36 nessai INFO    : it:  8368: n eval: 827959 H: 15.27 dlogZ: 42637.105 logZ: -88076.736 +/- 0.124 logLmax: -45431.26
# 07-15 00:40 nessai INFO    : Checkpointing nested sampling
# 07-15 00:40 nessai INFO    : it:  8392: n eval: 837959 H: 15.26 dlogZ: 42264.047 logZ: -87703.703 +/- 0.124 logLmax: -45431.26
# 07-15 00:44 nessai INFO    : it:  8413: n eval: 847959 H: 15.32 dlogZ: 42000.028 logZ: -87439.704 +/- 0.124 logLmax: -45431.26
# 07-15 00:48 nessai INFO    : it:  8441: n eval: 857959 H: 15.35 dlogZ: 41522.565 logZ: -86962.269 +/- 0.124 logLmax: -45431.26
# 07-15 00:52 nessai INFO    : Checkpointing nested sampling
# 07-15 00:52 nessai INFO    : it:  8457: n eval: 867959 H: 15.07 dlogZ: 41357.012 logZ: -86796.732 +/- 0.123 logLmax: -45431.26
# 07-15 00:56 nessai INFO    : it:  8480: n eval: 877959 H: 15.39 dlogZ: 40885.098 logZ: -86324.841 +/- 0.124 logLmax: -45431.26
# 07-15 01:00 nessai INFO    : it:  8508: n eval: 887959 H: 15.17 dlogZ: 40545.617 logZ: -85985.389 +/- 0.123 logLmax: -45431.26
# 07-15 01:04 nessai INFO    : Checkpointing nested sampling
# 07-15 01:04 nessai INFO    : it:  8529: n eval: 897959 H: 15.44 dlogZ: 40077.050 logZ: -85516.842 +/- 0.124 logLmax: -45431.26
# 07-15 01:07 nessai INFO    : it:  8540: n eval: 905878 H: 15.28 dlogZ: 39917.318 logZ: -85357.121 +/- 0.124 logLmax: -45431.26
# 07-15 01:11 nessai INFO    : it:  8560: n eval: 915878 H: 15.47 dlogZ: 39502.671 logZ: -84942.494 +/- 0.124 logLmax: -45431.26
# 07-15 01:15 nessai INFO    : Checkpointing nested sampling
# 07-15 01:15 nessai INFO    : it:  8582: n eval: 925878 H: 15.49 dlogZ: 39174.514 logZ: -84614.359 +/- 0.124 logLmax: -45431.26
# 07-15 01:19 nessai INFO    : it:  8601: n eval: 935878 H: 14.87 dlogZ: 38836.859 logZ: -84276.724 +/- 0.122 logLmax: -45431.26
# 07-15 01:23 nessai INFO    : it:  8615: n eval: 945878 H: 15.52 dlogZ: 38692.114 logZ: -84131.992 +/- 0.125 logLmax: -45431.26
# 07-15 01:27 nessai INFO    : Checkpointing nested sampling
# 07-15 01:27 nessai INFO    : it:  8636: n eval: 955878 H: 15.54 dlogZ: 38321.451 logZ: -83761.351 +/- 0.125 logLmax: -45431.26
# 07-15 01:31 nessai INFO    : it:  8658: n eval: 965878 H: 15.57 dlogZ: 37986.568 logZ: -83426.489 +/- 0.125 logLmax: -45431.26
# 07-15 01:35 nessai INFO    : it:  8680: n eval: 975878 H: 15.00 dlogZ: 37630.224 logZ: -83070.167 +/- 0.122 logLmax: -45431.26
# 07-15 01:39 nessai INFO    : Checkpointing nested sampling
# 07-15 01:39 nessai INFO    : it:  8700: n eval: 985878 H: 15.61 dlogZ: 37394.447 logZ: -82834.411 +/- 0.125 logLmax: -45431.26
# 07-15 01:43 nessai INFO    : it:  8719: n eval: 995878 H: 15.36 dlogZ: 37156.944 logZ: -82596.927 +/- 0.124 logLmax: -45431.26
# 07-15 01:47 nessai INFO    : it:  8739: n eval: 1005878 H: 15.65 dlogZ: 36778.043 logZ: -82218.045 +/- 0.125 logLmax: -45431.26
# 07-15 01:51 nessai INFO    : Checkpointing nested sampling
# 07-15 01:51 nessai INFO    : it:  8759: n eval: 1015878 H: 15.60 dlogZ: 36585.518 logZ: -82025.540 +/- 0.125 logLmax: -45431.26
# 07-15 01:56 nessai INFO    : it:  8778: n eval: 1025878 H: 15.51 dlogZ: 36365.110 logZ: -81805.151 +/- 0.125 logLmax: -45431.26
# 07-15 02:00 nessai INFO    : it:  8799: n eval: 1035878 H: 15.71 dlogZ: 36054.695 logZ: -81494.757 +/- 0.125 logLmax: -45431.26
# 07-15 02:04 nessai INFO    : Checkpointing nested sampling
# 07-15 02:04 nessai INFO    : it:  8811: n eval: 1045878 H: 15.53 dlogZ: 35806.665 logZ: -81246.739 +/- 0.125 logLmax: -45431.26
# 07-15 02:08 nessai INFO    : it:  8827: n eval: 1055878 H: 15.69 dlogZ: 35566.633 logZ: -81006.724 +/- 0.125 logLmax: -45431.26
# 07-15 02:12 nessai INFO    : it:  8840: n eval: 1065878 H: 15.75 dlogZ: 35432.268 logZ: -80872.371 +/- 0.125 logLmax: -45431.26
# 07-15 02:16 nessai INFO    : Checkpointing nested sampling
# 07-15 02:16 nessai INFO    : it:  8855: n eval: 1075878 H: 15.10 dlogZ: 35251.873 logZ: -80691.991 +/- 0.123 logLmax: -45431.26
# 07-15 02:20 nessai INFO    : it:  8877: n eval: 1085878 H: 15.11 dlogZ: 34909.636 logZ: -80349.777 +/- 0.123 logLmax: -45431.26
# 07-15 02:24 nessai INFO    : it:  8892: n eval: 1095878 H: 15.12 dlogZ: 34691.249 logZ: -80131.404 +/- 0.123 logLmax: -45431.26
# 07-15 02:28 nessai INFO    : Checkpointing nested sampling
# 07-15 02:28 nessai INFO    : it:  8914: n eval: 1105878 H: 15.82 dlogZ: 34412.067 logZ: -79852.244 +/- 0.126 logLmax: -45431.26
# 07-15 02:32 nessai INFO    : it:  8930: n eval: 1115878 H: 15.33 dlogZ: 34140.586 logZ: -79580.779 +/- 0.124 logLmax: -45431.26
# 07-15 02:36 nessai INFO    : it:  8947: n eval: 1125878 H: 15.85 dlogZ: 33844.461 logZ: -79284.671 +/- 0.126 logLmax: -45431.26
# 07-15 02:40 nessai INFO    : Checkpointing nested sampling
# 07-15 02:40 nessai INFO    : it:  8963: n eval: 1135878 H: 15.87 dlogZ: 33627.729 logZ: -79067.955 +/- 0.126 logLmax: -45431.26
# 07-15 02:44 nessai INFO    : it:  8983: n eval: 1145878 H: 15.89 dlogZ: 33436.661 logZ: -78876.907 +/- 0.126 logLmax: -45431.26
# 07-15 02:48 nessai INFO    : it:  8999: n eval: 1155878 H: 15.91 dlogZ: 33138.235 logZ: -78578.497 +/- 0.126 logLmax: -45431.26
# 07-15 02:48 nessai INFO    : it:  9000: Rolling KS test: D=0.028, p-value=0.2046
# 07-15 02:52 nessai INFO    : Checkpointing nested sampling
# 07-15 02:52 nessai INFO    : it:  9021: n eval: 1165878 H: 15.93 dlogZ: 32859.637 logZ: -78299.921 +/- 0.126 logLmax: -45431.26
# 07-15 02:56 nessai INFO    : it:  9052: n eval: 1175878 H: 15.94 dlogZ: 32411.226 logZ: -77851.542 +/- 0.126 logLmax: -45431.26
# 07-15 03:00 nessai INFO    : it:  9066: n eval: 1185878 H: 15.97 dlogZ: 32276.064 logZ: -77716.393 +/- 0.126 logLmax: -45431.26
# 07-15 03:04 nessai INFO    : Checkpointing nested sampling
# 07-15 03:04 nessai INFO    : it:  9086: n eval: 1195878 H: 15.99 dlogZ: 32007.079 logZ: -77447.429 +/- 0.126 logLmax: -45431.26
# 07-15 03:08 nessai INFO    : it:  9115: n eval: 1205878 H: 16.02 dlogZ: 31616.638 logZ: -77057.017 +/- 0.127 logLmax: -45431.26
# 07-15 03:12 nessai INFO    : it:  9133: n eval: 1215878 H: 16.04 dlogZ: 31326.030 logZ: -76766.427 +/- 0.127 logLmax: -45431.26
# 07-15 03:16 nessai INFO    : Checkpointing nested sampling
# 07-15 03:16 nessai INFO    : it:  9153: n eval: 1225878 H: 16.05 dlogZ: 31052.191 logZ: -76492.607 +/- 0.127 logLmax: -45431.26
# 07-15 03:20 nessai INFO    : it:  9167: n eval: 1235878 H: 16.06 dlogZ: 30902.394 logZ: -76342.824 +/- 0.127 logLmax: -45431.26
# 07-15 03:24 nessai INFO    : it:  9181: n eval: 1245878 H: 16.09 dlogZ: 30724.415 logZ: -76164.859 +/- 0.127 logLmax: -45431.26
# 07-15 03:28 nessai INFO    : Checkpointing nested sampling
# 07-15 03:28 nessai INFO    : it:  9196: n eval: 1255878 H: 16.10 dlogZ: 30636.873 logZ: -76077.332 +/- 0.127 logLmax: -45431.26
# 07-15 03:32 nessai INFO    : it:  9211: n eval: 1265878 H: 16.12 dlogZ: 30468.998 logZ: -75909.472 +/- 0.127 logLmax: -45431.26
# 07-15 03:36 nessai INFO    : it:  9227: n eval: 1275878 H: 15.61 dlogZ: 30338.986 logZ: -75779.476 +/- 0.125 logLmax: -45431.26
# 07-15 03:40 nessai INFO    : Checkpointing nested sampling
# 07-15 03:40 nessai INFO    : it:  9240: n eval: 1285878 H: 16.15 dlogZ: 30246.729 logZ: -75687.233 +/- 0.127 logLmax: -45431.26
# 07-15 03:44 nessai INFO    : it:  9260: n eval: 1295878 H: 15.70 dlogZ: 30021.112 logZ: -75461.635 +/- 0.125 logLmax: -45431.26
# 07-15 03:49 nessai INFO    : it:  9281: n eval: 1305878 H: 16.19 dlogZ: 29735.692 logZ: -75176.236 +/- 0.127 logLmax: -45431.26
# 07-15 03:53 nessai INFO    : Checkpointing nested sampling
# 07-15 03:53 nessai INFO    : it:  9293: n eval: 1315878 H: 16.20 dlogZ: 29616.457 logZ: -75057.013 +/- 0.127 logLmax: -45431.26
# 07-15 03:57 nessai INFO    : it:  9312: n eval: 1325878 H: 15.89 dlogZ: 29459.228 logZ: -74899.803 +/- 0.126 logLmax: -45431.26
# 07-15 04:01 nessai INFO    : it:  9324: n eval: 1335878 H: 15.49 dlogZ: 29352.906 logZ: -74793.493 +/- 0.124 logLmax: -45431.26
# 07-15 04:05 nessai INFO    : Checkpointing nested sampling
# 07-15 04:05 nessai INFO    : it:  9345: n eval: 1345878 H: 16.20 dlogZ: 29010.384 logZ: -74450.992 +/- 0.127 logLmax: -45431.26
# 07-15 04:09 nessai INFO    : it:  9355: n eval: 1355878 H: 16.26 dlogZ: 28892.199 logZ: -74332.817 +/- 0.128 logLmax: -45431.26
# 07-15 04:13 nessai INFO    : it:  9373: n eval: 1365878 H: 16.11 dlogZ: 28609.531 logZ: -74050.168 +/- 0.127 logLmax: -45431.26
# 07-15 04:17 nessai INFO    : Checkpointing nested sampling
# 07-15 04:17 nessai INFO    : it:  9387: n eval: 1375878 H: 16.29 dlogZ: 28447.679 logZ: -73888.329 +/- 0.128 logLmax: -45431.26
# 07-15 04:21 nessai INFO    : it:  9400: n eval: 1385878 H: 16.31 dlogZ: 28339.540 logZ: -73780.203 +/- 0.128 logLmax: -45431.26
# 07-15 04:25 nessai INFO    : it:  9412: n eval: 1395878 H: 16.19 dlogZ: 28186.311 logZ: -73626.987 +/- 0.127 logLmax: -45431.26
# 07-15 04:29 nessai INFO    : Checkpointing nested sampling
# 07-15 04:29 nessai INFO    : it:  9423: n eval: 1405878 H: 16.32 dlogZ: 28079.353 logZ: -73520.039 +/- 0.128 logLmax: -45431.26
# 07-15 04:33 nessai INFO    : it:  9436: n eval: 1415878 H: 16.34 dlogZ: 27961.468 logZ: -73402.167 +/- 0.128 logLmax: -45431.26
# 07-15 04:37 nessai INFO    : it:  9454: n eval: 1425878 H: 16.27 dlogZ: 27737.597 logZ: -73178.314 +/- 0.128 logLmax: -45431.26
# 07-15 04:41 nessai INFO    : Checkpointing nested sampling
# 07-15 04:41 nessai INFO    : it:  9473: n eval: 1435878 H: 15.85 dlogZ: 27510.244 logZ: -72950.980 +/- 0.126 logLmax: -45431.26
# 07-15 04:45 nessai INFO    : it:  9482: n eval: 1445878 H: 16.21 dlogZ: 27419.164 logZ: -72859.910 +/- 0.127 logLmax: -44858.12
# 07-15 04:49 nessai INFO    : it:  9496: n eval: 1455878 H: 16.40 dlogZ: 27824.027 logZ: -72691.642 +/- 0.128 logLmax: -44858.12
# 07-15 04:53 nessai INFO    : Checkpointing nested sampling
# 07-15 04:53 nessai INFO    : it:  9514: n eval: 1465878 H: 15.76 dlogZ: 27474.370 logZ: -72342.002 +/- 0.126 logLmax: -44858.12
# 07-15 04:57 nessai INFO    : it:  9520: n eval: 1475878 H: 16.43 dlogZ: 27407.708 logZ: -72275.346 +/- 0.128 logLmax: -44858.12
# 07-15 05:01 nessai INFO    : it:  9533: n eval: 1485878 H: 16.44 dlogZ: 27257.997 logZ: -72125.649 +/- 0.128 logLmax: -44858.12
# 07-15 05:05 nessai INFO    : Checkpointing nested sampling
# 07-15 05:05 nessai INFO    : it:  9544: n eval: 1495878 H: 16.45 dlogZ: 27032.316 logZ: -71899.979 +/- 0.128 logLmax: -44858.12
# 07-15 05:09 nessai INFO    : it:  9554: n eval: 1505878 H: 16.46 dlogZ: 26927.041 logZ: -71794.713 +/- 0.128 logLmax: -44858.12
# 07-15 05:13 nessai INFO    : it:  9568: n eval: 1515878 H: 16.48 dlogZ: 26809.306 logZ: -71676.992 +/- 0.128 logLmax: -44858.12
# 07-15 05:17 nessai INFO    : Checkpointing nested sampling
# 07-15 05:17 nessai INFO    : it:  9591: n eval: 1525878 H: 16.40 dlogZ: 26571.526 logZ: -71439.235 +/- 0.128 logLmax: -44858.12
# 07-15 05:21 nessai INFO    : it:  9601: n eval: 1535878 H: 16.14 dlogZ: 26511.149 logZ: -71378.868 +/- 0.127 logLmax: -44858.12
# 07-15 05:25 nessai INFO    : it:  9612: n eval: 1545878 H: 16.48 dlogZ: 26463.111 logZ: -71330.841 +/- 0.128 logLmax: -44858.12
# 07-15 05:30 nessai INFO    : Checkpointing nested sampling
# 07-15 05:30 nessai INFO    : it:  9622: n eval: 1555878 H: 16.53 dlogZ: 26367.669 logZ: -71235.409 +/- 0.129 logLmax: -44858.12
# 07-15 05:34 nessai INFO    : it:  9630: n eval: 1565878 H: 16.54 dlogZ: 26275.653 logZ: -71143.402 +/- 0.129 logLmax: -44858.12
# 07-15 05:38 nessai INFO    : it:  9644: n eval: 1575878 H: 15.95 dlogZ: 26150.551 logZ: -71018.314 +/- 0.126 logLmax: -44858.12
# 07-15 05:42 nessai INFO    : Checkpointing nested sampling
# 07-15 05:42 nessai INFO    : it:  9653: n eval: 1585878 H: 16.55 dlogZ: 26089.645 logZ: -70957.416 +/- 0.129 logLmax: -44858.12
# 07-15 05:46 nessai INFO    : it:  9661: n eval: 1595878 H: 16.57 dlogZ: 26019.379 logZ: -70887.159 +/- 0.129 logLmax: -44858.12
# 07-15 05:50 nessai INFO    : it:  9676: n eval: 1605878 H: 16.58 dlogZ: 25909.862 logZ: -70777.657 +/- 0.129 logLmax: -44858.12
# 07-15 05:54 nessai INFO    : Checkpointing nested sampling
# 07-15 05:54 nessai INFO    : it:  9684: n eval: 1615878 H: 16.59 dlogZ: 25846.895 logZ: -70714.697 +/- 0.129 logLmax: -44858.12
# 07-15 05:58 nessai INFO    : it:  9696: n eval: 1625878 H: 16.59 dlogZ: 25730.219 logZ: -70598.034 +/- 0.129 logLmax: -44858.12
# 07-15 06:02 nessai INFO    : it:  9709: n eval: 1635878 H: 16.61 dlogZ: 25602.420 logZ: -70470.248 +/- 0.129 logLmax: -44858.12
# 07-15 06:06 nessai INFO    : Checkpointing nested sampling
# 07-15 06:06 nessai INFO    : it:  9719: n eval: 1645878 H: 16.31 dlogZ: 25520.352 logZ: -70388.190 +/- 0.128 logLmax: -44858.12
# 07-15 06:10 nessai INFO    : it:  9735: n eval: 1655878 H: 16.64 dlogZ: 25402.726 logZ: -70270.580 +/- 0.129 logLmax: -44858.12
# 07-15 06:14 nessai INFO    : it:  9744: n eval: 1665878 H: 16.53 dlogZ: 25316.794 logZ: -70184.657 +/- 0.129 logLmax: -44858.12
# 07-15 06:18 nessai INFO    : Checkpointing nested sampling
# 07-15 06:18 nessai INFO    : it:  9756: n eval: 1675878 H: 16.65 dlogZ: 25173.256 logZ: -70041.131 +/- 0.129 logLmax: -44858.12
# 07-15 06:22 nessai INFO    : it:  9767: n eval: 1685878 H: 16.66 dlogZ: 25094.656 logZ: -69962.542 +/- 0.129 logLmax: -44858.12
# 07-15 06:26 nessai INFO    : it:  9785: n eval: 1695878 H: 16.08 dlogZ: 24929.103 logZ: -69797.007 +/- 0.127 logLmax: -44858.12
# 07-15 06:30 nessai INFO    : Checkpointing nested sampling
# 07-15 06:30 nessai INFO    : it:  9794: n eval: 1705878 H: 16.70 dlogZ: 24860.774 logZ: -69728.687 +/- 0.129 logLmax: -44858.12
# 07-15 06:34 nessai INFO    : it:  9809: n eval: 1715878 H: 16.71 dlogZ: 24713.412 logZ: -69581.340 +/- 0.129 logLmax: -44858.12
# 07-15 06:38 nessai INFO    : it:  9821: n eval: 1725878 H: 16.61 dlogZ: 24552.336 logZ: -69420.276 +/- 0.129 logLmax: -44858.12
# 07-15 06:42 nessai INFO    : Checkpointing nested sampling
# 07-15 06:42 nessai INFO    : it:  9825: n eval: 1735878 H: 16.45 dlogZ: 24498.019 logZ: -69365.963 +/- 0.128 logLmax: -44858.12
# 07-15 06:46 nessai INFO    : it:  9835: n eval: 1745878 H: 16.13 dlogZ: 24424.972 logZ: -69292.926 +/- 0.127 logLmax: -44858.12
# 07-15 06:50 nessai INFO    : it:  9843: n eval: 1755878 H: 16.57 dlogZ: 24366.508 logZ: -69234.470 +/- 0.129 logLmax: -44858.12
# 07-15 06:54 nessai INFO    : Checkpointing nested sampling
# 07-15 06:54 nessai INFO    : it:  9850: n eval: 1765878 H: 16.74 dlogZ: 24302.655 logZ: -69170.624 +/- 0.129 logLmax: -44858.12
# 07-15 06:58 nessai INFO    : it:  9864: n eval: 1775878 H: 16.17 dlogZ: 24109.737 logZ: -68977.719 +/- 0.127 logLmax: -44858.12
# 07-15 07:02 nessai INFO    : it:  9879: n eval: 1785878 H: 16.09 dlogZ: 23953.892 logZ: -68821.890 +/- 0.127 logLmax: -44858.12
# 07-15 07:07 nessai INFO    : Checkpointing nested sampling
# 07-15 07:07 nessai INFO    : it:  9889: n eval: 1795878 H: 16.76 dlogZ: 23877.001 logZ: -68745.008 +/- 0.129 logLmax: -44858.12
# 07-15 07:11 nessai INFO    : it:  9895: n eval: 1805878 H: 16.80 dlogZ: 23808.633 logZ: -68676.647 +/- 0.130 logLmax: -44858.12
# 07-15 07:15 nessai INFO    : it:  9905: n eval: 1815878 H: 16.81 dlogZ: 23742.845 logZ: -68610.869 +/- 0.130 logLmax: -44858.12
# 07-15 07:19 nessai INFO    : Checkpointing nested sampling
# 07-15 07:19 nessai INFO    : it:  9918: n eval: 1825878 H: 16.83 dlogZ: 23656.656 logZ: -68524.692 +/- 0.130 logLmax: -44858.12
# 07-15 07:23 nessai INFO    : it:  9930: n eval: 1835878 H: 16.27 dlogZ: 23505.306 logZ: -68373.355 +/- 0.128 logLmax: -44858.12
# 07-15 07:27 nessai INFO    : it:  9938: n eval: 1845878 H: 16.85 dlogZ: 23412.660 logZ: -68280.717 +/- 0.130 logLmax: -44858.12
# 07-15 07:31 nessai INFO    : Checkpointing nested sampling
# 07-15 07:31 nessai INFO    : it:  9944: n eval: 1855878 H: 16.70 dlogZ: 23348.065 logZ: -68216.128 +/- 0.129 logLmax: -44858.12
# 07-15 07:35 nessai INFO    : it:  9962: n eval: 1865878 H: 16.87 dlogZ: 23106.328 logZ: -67974.409 +/- 0.130 logLmax: -44858.12
# 07-15 07:39 nessai INFO    : it:  9976: n eval: 1875878 H: 16.88 dlogZ: 23035.986 logZ: -67904.080 +/- 0.130 logLmax: -44858.12
# 07-15 07:43 nessai INFO    : Checkpointing nested sampling
# 07-15 07:43 nessai INFO    : it:  9986: n eval: 1885878 H: 16.89 dlogZ: 22928.602 logZ: -67796.707 +/- 0.130 logLmax: -44858.12
# 07-15 07:47 nessai INFO    : it:  9997: n eval: 1895878 H: 16.32 dlogZ: 22823.704 logZ: -67691.820 +/- 0.128 logLmax: -44858.12
# 07-15 07:47 nessai INFO    : it: 10000: Rolling KS test: D=0.025, p-value=0.2818
# 07-15 07:51 nessai INFO    : it: 10002: n eval: 1905878 H: 16.87 dlogZ: 22768.051 logZ: -67636.172 +/- 0.130 logLmax: -44858.12
# 07-15 07:55 nessai INFO    : Checkpointing nested sampling
# 07-15 07:55 nessai INFO    : it: 10012: n eval: 1915878 H: 16.92 dlogZ: 22650.988 logZ: -67519.118 +/- 0.130 logLmax: -44858.12
# 07-15 07:59 nessai INFO    : it: 10024: n eval: 1925878 H: 16.91 dlogZ: 22597.887 logZ: -67466.029 +/- 0.130 logLmax: -44858.12
# 07-15 08:03 nessai INFO    : it: 10032: n eval: 1935878 H: 16.27 dlogZ: 22517.319 logZ: -67385.470 +/- 0.128 logLmax: -44858.12
# 07-15 08:07 nessai INFO    : Checkpointing nested sampling
# 07-15 08:07 nessai INFO    : it: 10043: n eval: 1945878 H: 16.68 dlogZ: 22445.474 logZ: -67313.636 +/- 0.129 logLmax: -44858.12
# 07-15 08:11 nessai INFO    : it: 10048: n eval: 1955878 H: 16.95 dlogZ: 22416.981 logZ: -67285.148 +/- 0.130 logLmax: -44858.12
# 07-15 08:15 nessai INFO    : it: 10058: n eval: 1965878 H: 16.96 dlogZ: 22306.012 logZ: -67174.189 +/- 0.130 logLmax: -44858.12
# 07-15 08:19 nessai INFO    : Checkpointing nested sampling
# 07-15 08:19 nessai INFO    : it: 10069: n eval: 1975878 H: 16.97 dlogZ: 22210.428 logZ: -67078.616 +/- 0.130 logLmax: -44858.12
# 07-15 08:23 nessai INFO    : it: 10079: n eval: 1985878 H: 16.99 dlogZ: 22149.799 logZ: -67017.997 +/- 0.130 logLmax: -44858.12
# 07-15 08:27 nessai INFO    : it: 10089: n eval: 1995878 H: 16.96 dlogZ: 22071.128 logZ: -66939.336 +/- 0.130 logLmax: -44858.12
# 07-15 08:31 nessai INFO    : Checkpointing nested sampling
# 07-15 08:31 nessai INFO    : it: 10098: n eval: 2005878 H: 17.01 dlogZ: 21929.473 logZ: -66797.690 +/- 0.130 logLmax: -44858.12
# 07-15 08:36 nessai INFO    : it: 10107: n eval: 2015878 H: 17.01 dlogZ: 21816.528 logZ: -66684.753 +/- 0.130 logLmax: -44858.12
# 07-15 08:40 nessai INFO    : it: 10119: n eval: 2025878 H: 17.00 dlogZ: 21681.490 logZ: -66549.728 +/- 0.130 logLmax: -44858.12
# 07-15 08:44 nessai INFO    : Checkpointing nested sampling
# 07-15 08:44 nessai INFO    : it: 10125: n eval: 2035878 H: 17.03 dlogZ: 21609.164 logZ: -66477.408 +/- 0.131 logLmax: -44858.12
# 07-15 08:48 nessai INFO    : it: 10138: n eval: 2045878 H: 17.04 dlogZ: 21437.292 logZ: -66305.548 +/- 0.131 logLmax: -44858.12
# 07-15 08:52 nessai INFO    : it: 10152: n eval: 2055878 H: 17.06 dlogZ: 21304.866 logZ: -66173.136 +/- 0.131 logLmax: -44858.12
# 07-15 08:56 nessai INFO    : Checkpointing nested sampling
# 07-15 08:56 nessai INFO    : it: 10161: n eval: 2065878 H: 17.07 dlogZ: 21246.505 logZ: -66114.785 +/- 0.131 logLmax: -44858.12
# 07-15 09:00 nessai INFO    : it: 10167: n eval: 2075878 H: 17.06 dlogZ: 21190.953 logZ: -66059.239 +/- 0.131 logLmax: -44858.12
# 07-15 09:04 nessai INFO    : it: 10178: n eval: 2085878 H: 16.73 dlogZ: 21115.985 logZ: -65984.282 +/- 0.129 logLmax: -44858.12
# 07-15 09:08 nessai INFO    : Checkpointing nested sampling
# 07-15 09:08 nessai INFO    : it: 10191: n eval: 2095878 H: 17.04 dlogZ: 21026.183 logZ: -65894.492 +/- 0.131 logLmax: -44858.12
# 07-15 09:12 nessai INFO    : it: 10202: n eval: 2105878 H: 17.11 dlogZ: 20926.817 logZ: -65795.138 +/- 0.131 logLmax: -44858.12
# 07-15 09:16 nessai INFO    : it: 10212: n eval: 2115878 H: 16.97 dlogZ: 20848.309 logZ: -65716.640 +/- 0.130 logLmax: -44858.12
# 07-15 09:20 nessai INFO    : Checkpointing nested sampling
# 07-15 09:20 nessai INFO    : it: 10220: n eval: 2125878 H: 16.26 dlogZ: 20809.689 logZ: -65678.028 +/- 0.128 logLmax: -44858.12
# 07-15 09:24 nessai INFO    : it: 10228: n eval: 2135878 H: 16.65 dlogZ: 20765.521 logZ: -65633.868 +/- 0.129 logLmax: -44858.12
# 07-15 09:28 nessai INFO    : it: 10231: n eval: 2145878 H: 17.14 dlogZ: 20728.188 logZ: -65596.538 +/- 0.131 logLmax: -44858.12
# 07-15 09:32 nessai INFO    : Checkpointing nested sampling
# 07-15 09:32 nessai INFO    : it: 10237: n eval: 2155878 H: 16.88 dlogZ: 20682.879 logZ: -65551.235 +/- 0.130 logLmax: -44858.12
# 07-15 09:36 nessai INFO    : it: 10245: n eval: 2165878 H: 17.15 dlogZ: 20624.023 logZ: -65492.387 +/- 0.131 logLmax: -44858.12
# 07-15 09:40 nessai INFO    : it: 10256: n eval: 2175878 H: 17.14 dlogZ: 20531.581 logZ: -65399.955 +/- 0.131 logLmax: -44858.12
# 07-15 09:44 nessai INFO    : Checkpointing nested sampling
# 07-15 09:44 nessai INFO    : it: 10265: n eval: 2185878 H: 16.50 dlogZ: 20458.741 logZ: -65327.125 +/- 0.128 logLmax: -44858.12
# 07-15 09:48 nessai INFO    : it: 10273: n eval: 2195878 H: 17.16 dlogZ: 20400.305 logZ: -65268.697 +/- 0.131 logLmax: -44858.12
# 07-15 09:53 nessai INFO    : it: 10288: n eval: 2205878 H: 16.86 dlogZ: 20287.018 logZ: -65155.425 +/- 0.130 logLmax: -44858.12
# 07-15 09:57 nessai INFO    : Checkpointing nested sampling
# 07-15 09:57 nessai INFO    : it: 10297: n eval: 2215878 H: 17.20 dlogZ: 20245.237 logZ: -65113.653 +/- 0.131 logLmax: -44858.12
# 07-15 10:01 nessai INFO    : it: 10305: n eval: 2225878 H: 17.05 dlogZ: 20178.662 logZ: -65047.085 +/- 0.131 logLmax: -44858.12
# 07-15 10:05 nessai INFO    : it: 10310: n eval: 2235878 H: 17.21 dlogZ: 20157.386 logZ: -65025.815 +/- 0.131 logLmax: -44858.12
# 07-15 10:09 nessai INFO    : Checkpointing nested sampling
# 07-15 10:09 nessai INFO    : it: 10320: n eval: 2245878 H: 17.23 dlogZ: 20065.768 logZ: -64934.207 +/- 0.131 logLmax: -44858.12
# 07-15 10:13 nessai INFO    : it: 10334: n eval: 2255878 H: 16.44 dlogZ: 19933.254 logZ: -64801.707 +/- 0.128 logLmax: -44858.12
# 07-15 10:17 nessai INFO    : it: 10341: n eval: 2265878 H: 17.25 dlogZ: 19862.397 logZ: -64730.857 +/- 0.131 logLmax: -44858.12
# 07-15 10:21 nessai INFO    : Checkpointing nested sampling
# 07-15 10:21 nessai INFO    : it: 10352: n eval: 2275878 H: 16.47 dlogZ: 19798.253 logZ: -64666.724 +/- 0.128 logLmax: -44858.12
# 07-15 10:25 nessai INFO    : it: 10364: n eval: 2285878 H: 17.27 dlogZ: 19690.296 logZ: -64558.778 +/- 0.131 logLmax: -44858.12
# 07-15 10:29 nessai INFO    : it: 10376: n eval: 2295878 H: 16.91 dlogZ: 19619.061 logZ: -64487.556 +/- 0.130 logLmax: -44858.12
# 07-15 10:33 nessai INFO    : Checkpointing nested sampling
# 07-15 10:33 nessai INFO    : it: 10380: n eval: 2305878 H: 16.66 dlogZ: 19603.907 logZ: -64472.406 +/- 0.129 logLmax: -44858.12
# 07-15 10:37 nessai INFO    : it: 10388: n eval: 2315878 H: 17.29 dlogZ: 19532.476 logZ: -64400.983 +/- 0.132 logLmax: -44858.12
# 07-15 10:42 nessai INFO    : it: 10396: n eval: 2325878 H: 16.66 dlogZ: 19483.566 logZ: -64352.081 +/- 0.129 logLmax: -44858.12
# 07-15 10:46 nessai INFO    : Checkpointing nested sampling
# 07-15 10:46 nessai INFO    : it: 10402: n eval: 2335878 H: 17.31 dlogZ: 19402.402 logZ: -64270.922 +/- 0.132 logLmax: -44858.12
# 07-15 10:50 nessai INFO    : it: 10406: n eval: 2345878 H: 17.31 dlogZ: 19344.517 logZ: -64213.042 +/- 0.132 logLmax: -44858.12
# 07-15 10:54 nessai INFO    : it: 10415: n eval: 2355878 H: 17.32 dlogZ: 19270.714 logZ: -64139.248 +/- 0.132 logLmax: -44858.12
# 07-15 10:58 nessai INFO    : Checkpointing nested sampling
# 07-15 10:58 nessai INFO    : it: 10424: n eval: 2365878 H: 17.33 dlogZ: 19193.705 logZ: -64062.248 +/- 0.132 logLmax: -44858.12
# 07-15 11:02 nessai INFO    : it: 10431: n eval: 2375878 H: 17.34 dlogZ: 19126.320 logZ: -63994.869 +/- 0.132 logLmax: -44858.12
# 07-15 11:06 nessai INFO    : it: 10440: n eval: 2385878 H: 17.26 dlogZ: 19072.142 logZ: -63940.700 +/- 0.131 logLmax: -44858.12
# 07-15 11:10 nessai INFO    : Checkpointing nested sampling
# 07-15 11:10 nessai INFO    : it: 10448: n eval: 2395878 H: 17.36 dlogZ: 18996.052 logZ: -63864.619 +/- 0.132 logLmax: -44858.12
# 07-15 11:14 nessai INFO    : it: 10459: n eval: 2405878 H: 16.99 dlogZ: 18918.010 logZ: -63786.588 +/- 0.130 logLmax: -44858.12
# 07-15 11:18 nessai INFO    : it: 10465: n eval: 2415878 H: 17.05 dlogZ: 18888.911 logZ: -63757.495 +/- 0.131 logLmax: -44858.12
# 07-15 11:22 nessai INFO    : Checkpointing nested sampling
# 07-15 11:22 nessai INFO    : it: 10473: n eval: 2425878 H: 17.38 dlogZ: 18818.086 logZ: -63686.677 +/- 0.132 logLmax: -44858.12
# 07-15 11:26 nessai INFO    : it: 10483: n eval: 2435878 H: 17.39 dlogZ: 18754.656 logZ: -63623.258 +/- 0.132 logLmax: -44858.12
# 07-15 11:30 nessai INFO    : it: 10492: n eval: 2445878 H: 17.18 dlogZ: 18711.494 logZ: -63580.104 +/- 0.131 logLmax: -44858.12
# 07-15 11:35 nessai INFO    : Checkpointing nested sampling
# 07-15 11:35 nessai INFO    : it: 10500: n eval: 2455878 H: 17.41 dlogZ: 18659.694 logZ: -63528.313 +/- 0.132 logLmax: -44858.12
# 07-15 11:39 nessai INFO    : it: 10507: n eval: 2465878 H: 17.41 dlogZ: 18604.080 logZ: -63472.706 +/- 0.132 logLmax: -44858.12
# 07-15 11:43 nessai INFO    : it: 10515: n eval: 2475878 H: 16.72 dlogZ: 18565.206 logZ: -63433.840 +/- 0.129 logLmax: -44858.12
# 07-15 11:47 nessai INFO    : Checkpointing nested sampling
# 07-15 11:47 nessai INFO    : it: 10525: n eval: 2485878 H: 16.42 dlogZ: 18484.006 logZ: -63352.650 +/- 0.128 logLmax: -44858.12
# ...
# 07-16 06:01 nessai INFO    : Checkpointing nested sampling
# 07-16 06:01 nessai INFO    : it: 12245: n eval: 5164632 H: 18.32 dlogZ: 11069.553 logZ: -54246.966 +/- 0.135 logLmax: -43165.17
# 07-16 06:05 nessai INFO    : it: 12255: n eval: 5174632 H: 19.13 dlogZ: 11028.602 logZ: -54206.026 +/- 0.138 logLmax: -43165.17
# 07-16 06:09 nessai INFO    : it: 12260: n eval: 5184632 H: 19.17 dlogZ: 11006.084 logZ: -54183.512 +/- 0.138 logLmax: -43165.17
# 07-16 06:13 nessai INFO    : Checkpointing nested sampling
# 07-16 06:13 nessai INFO    : it: 12263: n eval: 5194632 H: 19.17 dlogZ: 10987.485 logZ: -54164.916 +/- 0.138 logLmax: -43165.17
# 07-16 06:18 nessai INFO    : it: 12267: n eval: 5204632 H: 18.60 dlogZ: 10962.740 logZ: -54140.175 +/- 0.136 logLmax: -43165.17
# 07-16 06:22 nessai INFO    : it: 12273: n eval: 5214632 H: 18.60 dlogZ: 10944.177 logZ: -54121.618 +/- 0.136 logLmax: -43165.17
# 07-16 06:26 nessai INFO    : Checkpointing nested sampling
# 07-16 06:26 nessai INFO    : it: 12278: n eval: 5224632 H: 19.04 dlogZ: 10918.001 logZ: -54095.447 +/- 0.138 logLmax: -43165.17
# 07-16 06:30 nessai INFO    : it: 12283: n eval: 5234632 H: 19.15 dlogZ: 10886.120 logZ: -54063.571 +/- 0.138 logLmax: -43165.17
# 07-16 06:34 nessai INFO    : it: 12289: n eval: 5244632 H: 19.18 dlogZ: 10868.225 logZ: -54045.682 +/- 0.138 logLmax: -43165.17
# 07-16 06:38 nessai INFO    : Checkpointing nested sampling
# 07-16 06:38 nessai INFO    : it: 12294: n eval: 5254632 H: 18.91 dlogZ: 10844.504 logZ: -54021.966 +/- 0.138 logLmax: -43165.17
# 07-16 06:42 nessai INFO    : it: 12301: n eval: 5264632 H: 19.14 dlogZ: 10802.201 logZ: -53979.671 +/- 0.138 logLmax: -43165.17
# 07-16 06:46 nessai INFO    : it: 12309: n eval: 5274632 H: 19.20 dlogZ: 10772.050 logZ: -53949.528 +/- 0.139 logLmax: -43165.17
# 07-16 06:50 nessai INFO    : Checkpointing nested sampling
# 07-16 06:50 nessai INFO    : it: 12315: n eval: 5284632 H: 19.22 dlogZ: 10735.632 logZ: -53913.115 +/- 0.139 logLmax: -43165.17
# 07-16 06:54 nessai INFO    : it: 12320: n eval: 5294632 H: 18.27 dlogZ: 10728.300 logZ: -53905.788 +/- 0.135 logLmax: -43165.17
# 07-16 06:59 nessai INFO    : it: 12323: n eval: 5304632 H: 19.23 dlogZ: 10709.594 logZ: -53887.085 +/- 0.139 logLmax: -43165.17
# 07-16 07:03 nessai INFO    : Checkpointing nested sampling
# 07-16 07:03 nessai INFO    : it: 12327: n eval: 5314632 H: 18.58 dlogZ: 10687.813 logZ: -53865.308 +/- 0.136 logLmax: -43165.17
# 07-16 07:07 nessai INFO    : it: 12332: n eval: 5324632 H: 19.18 dlogZ: 10676.002 logZ: -53853.502 +/- 0.138 logLmax: -43165.17
# 07-16 07:11 nessai INFO    : it: 12335: n eval: 5334632 H: 19.24 dlogZ: 10647.440 logZ: -53824.943 +/- 0.139 logLmax: -43165.17
# 07-16 07:15 nessai INFO    : Checkpointing nested sampling
# 07-16 07:15 nessai INFO    : it: 12342: n eval: 5344632 H: 18.29 dlogZ: 10623.217 logZ: -53800.727 +/- 0.135 logLmax: -43165.17
# 07-16 07:19 nessai INFO    : it: 12353: n eval: 5354632 H: 18.74 dlogZ: 10573.451 logZ: -53750.972 +/- 0.137 logLmax: -43165.17
# 07-16 07:23 nessai INFO    : it: 12359: n eval: 5364632 H: 19.21 dlogZ: 10547.285 logZ: -53724.812 +/- 0.139 logLmax: -43165.17
# 07-16 07:27 nessai INFO    : Checkpointing nested sampling
# 07-16 07:27 nessai INFO    : it: 12363: n eval: 5374632 H: 18.99 dlogZ: 10540.797 logZ: -53718.328 +/- 0.138 logLmax: -43165.17
# 07-16 07:31 nessai INFO    : it: 12371: n eval: 5384632 H: 19.23 dlogZ: 10504.583 logZ: -53682.122 +/- 0.139 logLmax: -43165.17
